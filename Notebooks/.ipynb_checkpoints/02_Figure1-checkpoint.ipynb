# %% [markdown]
# ### Table of contents
# 1. [Figure 1C. UMAP of integrated cohort](#1)
# 2. [Figure 1D. Heatmap of Benci/Minn IFNG.GS and ISG.RS signatures. Violins of signatures across broad lineages](#2)
# 3. [Figure 1E. Heatmap of differentially expressed putative ISGs across broad cell types](#3)
# 4. [Figure 1F. Lollipop plots showing top IFN1 and IFNG skewed ISGs for Tumor, TAM, and CD8s](#4)
# 5. [Manually check over metadata, cross-referencing against original studies](#5)
# 6. [Figure 1B. Prepare metadata for CoMut](#6)

# %%
library(harmony)
library(stringr)
library(Seurat)
library(useful)
library(dplyr)
library(ggpubr)
library(glue)
library(RColorBrewer)
library(ggpubr)
library(ggrepel)
library(lmerTest)
library(Scillus)
library(cowplot)
library(hrbrthemes)

set.seed(1234)

options(repr.plot.width=12, repr.plot.height=9)
# Out:
# Loading required package: Rcpp
#
# Attaching SeuratObject
#
# Attaching sp
#
# Loading required package: ggplot2
#
#
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: lme4
#
# Loading required package: Matrix
#
#
# Attaching package: 'lmerTest'
#
#
# The following object is masked from 'package:lme4':
#
#     lmer
#
#
# The following object is masked from 'package:stats':
#
#     step
#
#
#
# Attaching package: 'cowplot'
#
#
# The following object is masked from 'package:ggpubr':
#
#     get_legend
#
#
# NOTE: Either Arial Narrow or Roboto Condensed fonts are required to use these themes.
#
#       Please use hrbrthemes::import_roboto_condensed() to install Roboto Condensed and
#
#       if Arial Narrow is not on your system, please see https://bit.ly/arialnarrow

# %% [markdown]
# ### Figure 1C. UMAP of integrated cohort <a name="1"></a>

# %% [markdown]
# ### Read in data and colors

# %%
options(repr.plot.width=9.5, repr.plot.height=8)

goi = readRDS("../Signatures/manuscript_goi_hallmark_benciminn_curated.RDS")
length(goi)

goi

##

celltype_cols = readRDS(file = "../Data_Objects/celltype_cols.RDS")
celltype_cols

##

seur_full = readRDS("../Data_Objects/seur_full_BBK_Manuscript.RDS")
table(seur_full$IO_Treated)

Idents(seur_full) = "BBK_Broad_Celltype"

seur_full = subset(seur_full, idents = c("Contam","Omitted"), invert = T)

seur_full$BBK_Broad_Celltype = factor(seur_full$BBK_Broad_Celltype, levels = c("Tumor","Fibroblast","Perivascular cell","Endothelial","TAM","Monocyte","DC","CD8","CD8 NK-like","NK","T-Helper","T-reg","B cell","Plasma cell"))
Idents(seur_full) = "BBK_Broad_Celltype"
table(Idents(seur_full))

DimPlot(seur_full, label = T, cols = celltype_cols[levels(Idents(seur_full))], shuffle = F)
# Out:
# [1] 259
#   [1] "ADAR"     "B2M"      "BATF2"    "BST2"     "C1S"      "CASP1"
#   [7] "CASP8"    "CCRL2"    "CD47"     "CD74"     "CMPK2"    "CMTR1"
#  [13] "CNP"      "CSF1"     "CXCL10"   "CXCL11"   "DDX60"    "DHX58"
#  [19] "EIF2AK2"  "ELF1"     "EPSTI1"   "GBP2"     "GBP4"     "GMPR"
#  [25] "HELZ2"    "HERC6"    "HLA-C"    "IFI27"    "IFI30"    "IFI35"
#  [31] "IFI44"    "IFI44L"   "IFIH1"    "IFIT2"    "IFIT3"    "IFITM1"
#  [37] "IFITM2"   "IFITM3"   "IL15"     "IL4R"     "IL7"      "IRF1"
#  [43] "IRF2"     "IRF7"     "IRF9"     "ISG15"    "ISG20"    "LAMP3"
#  [49] "LAP3"     "LGALS3BP" "LPAR6"    "LY6E"     "MOV10"    "MVB12A"
#  [55] "MX1"      "NCOA7"    "NMI"      "NUB1"     "OAS1"     "OASL"
#  [61] "OGFR"     "PARP12"   "PARP14"   "PARP9"    "PLSCR1"   "PNPT1"
#  [67] "PROCR"    "PSMA3"    "PSMB8"    "PSMB9"    "PSME1"    "PSME2"
#  [73] "RIPK2"    "RNF31"    "RSAD2"    "RTP4"     "SAMD9"    "SAMD9L"
#  [79] "SELL"     "SLC25A28" "SP110"    "STAT2"    "TAP1"     "TDRD7"
#  [85] "TENT5A"   "TMEM140"  "TRAFD1"   "TRIM14"   "TRIM21"   "TRIM25"
#  [91] "TRIM26"   "TRIM5"    "TXNIP"    "UBA7"     "UBE2L6"   "USP18"
#  [97] "WARS1"    "APOL6"    "ARID5B"   "ARL4A"    "AUTS2"    "BANK1"
# [103] "BPGM"     "BTG1"     "C1R"      "CASP3"    "CASP4"    "CASP7"
# [109] "CCL2"     "CCL5"     "CCL7"     "CD274"    "CD38"     "CD40"
# [115] "CD69"     "CD86"     "CDKN1A"   "CFB"      "CFH"      "CIITA"
# [121] "CMKLR1"   "CSF2RB"   "CXCL9"    "EIF4E3"   "FAS"      "FCGR1A"
# [127] "FGL2"     "FPR1"     "GBP6"     "GCH1"     "GPR18"    "GZMA"
# [133] "HIF1A"    "HLA-A"    "HLA-B"    "HLA-DMA"  "HLA-DQA1" "HLA-DRB1"
# [139] "HLA-G"    "ICAM1"    "IDO1"     "IFIT1"    "IFNAR2"   "IL10RA"
# [145] "IL15RA"   "IL18BP"   "IL2RB"    "IL6"      "IRF4"     "IRF5"
# [151] "IRF8"     "ISOC1"    "ITGB7"    "JAK2"     "KLRK1"    "LATS2"
# [157] "LCP2"     "LYSMD2"   "MARCHF1"  "METTL7B"  "MT2A"     "MTHFD2"
# [163] "MVP"      "MX2"      "MYD88"    "NAMPT"    "NCOA3"    "NFKB1"
# [169] "NFKBIA"   "NLRC5"    "NOD1"     "NUP93"    "OAS2"     "OAS3"
# [175] "P2RY14"   "PDE4B"    "PELI1"    "PFKP"     "PIM1"     "PLA2G4A"
# [181] "PML"      "PNP"      "PSMA2"    "PSMB10"   "PSMB2"    "PTGS2"
# [187] "PTPN1"    "PTPN2"    "PTPN6"    "RAPGEF6"  "RBCK1"    "RIGI"
# [193] "RIPK1"    "RNF213"   "SAMHD1"   "SECTM1"   "SELP"     "SERPING1"
# [199] "SLAMF7"   "SOCS1"    "SOCS3"    "SOD2"     "SPPL2A"   "SRI"
# [205] "SSPN"     "ST3GAL5"  "ST8SIA4"  "STAT1"    "STAT3"    "STAT4"
# [211] "TAPBP"    "TNFAIP2"  "TNFAIP3"  "TNFAIP6"  "TNFSF10"  "TOR1B"
# [217] "UPP1"     "VAMP5"    "VAMP8"    "VCAM1"    "XAF1"     "XCL1"
# [223] "ZBP1"     "ZNFX1"    "HSD17B1"  "CA2"      "CCNA1"    "CXCL1"
# [229] "GALC"     "IFI6"     "MCL1"     "ROBO1"    "SLC6A15"  "THBS1"
# [235] "TIMP3"    "DDX58"    "WARS"     "MARCH1"   "PRIC285"  "FTSJD2"
# [241] "NOS2"     "PDCD1LG2" "LGALS9"   "HMGB1"    "CEACAM1"  "FGL1"
# [247] "HLA-DRA"  "NECTIN2"  "PVR"      "SIGLEC10" "TNFRSF14" "VSIG4"
# [253] "VSIR"     "HLA-E"    "LGALS3"   "CD80"     "LILRB1"   "IL10"
# [259] "CCL22"
#             Tumor               TAM               CD8       Plasma cell
#         "#A0BAAC"         "#7FC97F"         "#C2AFCE"         "#E4B9A3"
#                DC       Endothelial          T-Helper                NK
#         "#FDC988"         "#FEEB93"         "#D1DD9E"         "#658DAA"
#          Monocyte             T-reg            B cell       CD8 NK-like
#         "#704BA0"         "#D31286"         "#DD2456"         "#C2541E"
#        Fibroblast Perivascular cell            Contam           Omitted
#         "#95603B"         "#666666"          "grey95"          "grey95"
# IO Exposed   IO Naive
#     104514     184254
#             Tumor        Fibroblast Perivascular cell       Endothelial
#             18994               277              1691              1781
#               TAM          Monocyte                DC               CD8
#             27684             15072              4522             88457
#       CD8 NK-like                NK          T-Helper             T-reg
#             13563             20422             22656              8618
#            B cell       Plasma cell
#              3330              1304
# Rasterizing points since number of points exceeds 100,000.
# To disable this behavior set `raster=FALSE`
# plot without title

# %%
options(repr.plot.width=9.5, repr.plot.height=8)

DimPlot(seur_full, label = T, cols = celltype_cols[levels(Idents(seur_full))], shuffle = F)

ggsave("../Figures/Figure1/Figure1C_UMAP_seur_full_raster.pdf", width = 9.5, height = 8)
# Out:
# Rasterizing points since number of points exceeds 100,000.
# To disable this behavior set `raster=FALSE`
# plot without title

# %%
options(repr.plot.width=9.5, repr.plot.height=8)

DimPlot(seur_full, label = T, cols = celltype_cols[levels(Idents(seur_full))], shuffle = F,raster = F)

ggsave("../Figures/Figure1/Figure1C_UMAP_seur_full_rasterFALSE.pdf", width = 9.5, height = 8)
# Out:
# plot without title

# %% [markdown]
# ### Figure 1D. Heatmap of Benci/Minn IFNG.GS and ISG.RS signatures. Violins of signatures across broad lineages <a name="2"></a>

# %% [markdown]
# ### For this and later panels, we first make an object where expression is averaged within each cell type and sample.

# %%
options(repr.plot.width=15, repr.plot.height=9)

cluster.averages <- AverageExpression(seur_full, return.seurat = TRUE, group.by = c("BBK_Broad_Celltype","Sample"))
Idents(cluster.averages) = factor(Idents(cluster.averages), levels = c("Tumor","Fibroblast","Perivascular cell","Endothelial","TAM","Monocyte","DC","CD8","CD8 NK-like","NK","T-Helper","T-reg","B cell","Plasma cell"))

DoHeatmap(cluster.averages, features = intersect(goi, row.names(seur_full@assays$RNA@data)), size = 3, 
    draw.lines = TRUE)
# Out:
# Centering and scaling data matrix
# plot without title

# %% [markdown]
# ### Update this cluster.averages object with metadata

# %%
head(cluster.averages@meta.data)

celltypes = unique(as.character(cluster.averages@meta.data$orig.ident))

resvec = c()

for (i in 1:length(celltypes)){
    
    sub = row.names(subset(cluster.averages@meta.data, orig.ident == celltypes[i]))
    sub = str_replace_all(sub, paste(celltypes[i],"_",sep = ""),"")
    resvec = c(resvec, sub)

}

resvec

cluster.averages@meta.data$Sample = resvec
head(cluster.averages@meta.data)

metasub = seur_full@meta.data[,c("Cohort","Sample","Stage_Corrected","Stage_Corrected_EarlyLate","Biopsy","IO","TKI","Treated","IO_Treated")]
row.names(metasub) = c(1:nrow(metasub))
corner(metasub)

metasub = metasub %>% group_by_at(vars(Cohort:IO_Treated)) %>%
  summarize_all(paste, collapse=",")
corner(metasub)

cluster_meta_df = cluster.averages@meta.data
cluster_meta_df$rownames = row.names(cluster_meta_df)

test = left_join(cluster_meta_df, metasub, by = "Sample")
row.names(test) = test$rownames

dim(test)
head(test)
# Out:
#                               orig.ident nCount_RNA nFeature_RNA
# Tumor_5pool1_2                Tumor      10000      18069
# Tumor_Bi_0600855_T3           Tumor      10000      15019
# Tumor_Bi_0600906_T1           Tumor      10000      17420
# Tumor_Bi_0600913_T1           Tumor      10000      17015
# Tumor_Bi_0600915_T1_TrueTumor Tumor      10000      19577
# Tumor_Bi_0600916_T1           Tumor      10000       3093
#   [1] "5pool1_2"                         "Bi_0600855_T3"
#   [3] "Bi_0600906_T1"                    "Bi_0600913_T1"
#   [5] "Bi_0600915_T1_TrueTumor"          "Bi_0600916_T1"
#   [7] "Bi_DFCI_0600876_T1"               "Bi_DFCI_0600890_T1"
#   [9] "IpiNivo_Mixed_Center"             "IpiNivo_Mixed_Far"
#  [11] "IpiNivo_Mixed_Near"               "IpiNivo_Resistant_Center"
#  [13] "IpiNivo_Resistant_Far"            "IpiNivo_Resistant_LymphNode"
#  [15] "IpiNivo_Resistant_Near"           "NivoExposed_LowerLateral"
#  [17] "NivoExposed_LowerMedial"          "NivoExposed_SupraLateral"
#  [19] "Pool70-10"                        "Pool70-6"
#  [21] "Pool71-5"                         "Pool71-6"
#  [23] "Pool72-2"                         "Pool72-4"
#  [25] "Pool73-3"                         "Pool73-4"
#  [27] "Pool73-5"                         "Pool73-6"
#  [29] "UT1_Center"                       "UT1_Upper"
#  [31] "UT2_Center"                       "UT2_Far"
#  [33] "UT2_Near"                         "Bi_0600906_T1"
#  [35] "Bi_0600912_T1"                    "Bi_0600913_T1"
#  [37] "IpiNivo_CompleteResponse_Center"  "IpiNivo_CompleteResponse_Lateral"
#  [39] "IpiNivo_CompleteResponse_Medial"  "IpiNivo_Mixed_Near"
#  [41] "IpiNivo_Resistant_Center"         "IpiNivo_Resistant_Far"
#  [43] "IpiNivo_Resistant_LymphNode"      "IpiNivo_Resistant_Near"
#  [45] "NivoExposed_LowerLateral"         "NivoExposed_LowerMedial"
#  [47] "NivoExposed_SupraLateral"         "Pool70-6"
#  [49] "Pool72-2"                         "UT1_Center"
#  [51] "UT1_Lower"                        "UT1_Upper"
#  [53] "UT2_Center"                       "UT2_Far"
#  [55] "UT2_Near"                         "Bi_0600906_T1"
#  [57] "Bi_0600913_T1"                    "Bi_0600915_T1_TrueTumor"
#  [59] "IpiNivo_CompleteResponse_Lateral" "IpiNivo_CompleteResponse_Medial"
#  [61] "IpiNivo_Mixed_Center"             "IpiNivo_Mixed_Far"
#  [63] "IpiNivo_Mixed_Near"               "IpiNivo_Resistant_Center"
#  [65] "IpiNivo_Resistant_Far"            "IpiNivo_Resistant_LymphNode"
#  [67] "IpiNivo_Resistant_Near"           "NivoExposed_LowerLateral"
#  [69] "NivoExposed_LowerMedial"          "NivoExposed_SupraLateral"
#  [71] "Pool70-6"                         "Pool71-3"
#  [73] "Pool73-4"                         "Pool73-6"
#  [75] "UT1_Center"                       "UT1_Lower"
#  [77] "UT1_Upper"                        "UT2_Center"
#  [79] "UT2_Far"                          "UT2_Near"
#  [81] "5pool1_2"                         "Bi_0600906_T1"
#  [83] "Bi_0600912_T1"                    "Bi_0600913_T1"
#  [85] "Bi_0600915_T1_TrueTumor"          "Bi_DFCI_0600876_T1"
#  [87] "IpiNivo_CompleteResponse_Center"  "IpiNivo_CompleteResponse_Lateral"
#  [89] "IpiNivo_CompleteResponse_Medial"  "IpiNivo_Mixed_Center"
#  [91] "IpiNivo_Mixed_Far"                "IpiNivo_Mixed_Near"
#  [93] "IpiNivo_Resistant_Center"         "IpiNivo_Resistant_Far"
#  [95] "IpiNivo_Resistant_LymphNode"      "IpiNivo_Resistant_Near"
#  [97] "NivoExposed_LowerLateral"         "NivoExposed_LowerMedial"
#  [99] "NivoExposed_SupraLateral"         "Pool70-10"
# [101] "Pool70-6"                         "Pool70-8"
# [103] "Pool71-3"                         "Pool71-8"
# [105] "Pool72-10"                        "Pool72-2"
# [107] "Pool72-4"                         "Pool73-3"
# [109] "Pool73-4"                         "Pool73-5"
# [111] "Pool73-6"                         "UT1_Center"
# [113] "UT1_Lower"                        "UT1_Upper"
# [115] "UT2_Far"                          "UT2_Near"
# [117] "5pool1_2"                         "Bi_0600855_T3"
# [119] "Bi_0600906_T1"                    "Bi_0600912_T1"
# [121] "Bi_0600913_T1"                    "Bi_0600915_T1_TrueTumor"
# [123] "Bi_0600916_T1"                    "Bi_DFCI_0600876_T1"
# [125] "Bi_DFCI_0600890_T1"               "IpiNivo_CompleteResponse_Center"
# [127] "IpiNivo_CompleteResponse_Lateral" "IpiNivo_CompleteResponse_Medial"
# [129] "IpiNivo_Mixed_Center"             "IpiNivo_Mixed_Far"
# [131] "IpiNivo_Mixed_Near"               "IpiNivo_Resistant_Center"
# [133] "IpiNivo_Resistant_Far"            "IpiNivo_Resistant_LymphNode"
# [135] "IpiNivo_Resistant_Near"           "NivoExposed_LowerLateral"
# [137] "NivoExposed_LowerMedial"          "NivoExposed_SupraLateral"
# [139] "Pool70-10"                        "Pool70-6"
# [141] "Pool70-8"                         "Pool71-3"
# [143] "Pool71-5"                         "Pool71-6"
# [145] "Pool71-8"                         "Pool72-2"
# [147] "Pool72-4"                         "Pool73-3"
# [149] "Pool73-4"                         "Pool73-5"
# [151] "Pool73-6"                         "UT1_Center"
# [153] "UT1_Lower"                        "UT1_Upper"
# [155] "UT2_Center"                       "UT2_Far"
# [157] "UT2_Near"                         "5pool1_2"
# [159] "Bi_0600855_T3"                    "Bi_0600906_T1"
# [161] "Bi_0600912_T1"                    "Bi_0600913_T1"
# [163] "Bi_0600915_T1_TrueTumor"          "Bi_0600916_T1"
# [165] "Bi_DFCI_0600876_T1"               "Bi_DFCI_0600890_T1"
# [167] "IpiNivo_CompleteResponse_Center"  "IpiNivo_CompleteResponse_Lateral"
# [169] "IpiNivo_CompleteResponse_Medial"  "IpiNivo_Mixed_Center"
# [171] "IpiNivo_Mixed_Far"                "IpiNivo_Mixed_Near"
# [173] "IpiNivo_Resistant_Center"         "IpiNivo_Resistant_Far"
# [175] "IpiNivo_Resistant_LymphNode"      "IpiNivo_Resistant_Near"
# [177] "NivoExposed_LowerLateral"         "NivoExposed_LowerMedial"
# [179] "NivoExposed_SupraLateral"         "Pool70-10"
# [181] "Pool70-6"                         "Pool70-8"
# [183] "Pool71-3"                         "Pool71-5"
# [185] "Pool71-6"                         "Pool71-8"
# [187] "Pool72-10"                        "Pool72-2"
# [189] "Pool72-4"                         "Pool73-3"
# [191] "Pool73-4"                         "Pool73-5"
# [193] "Pool73-6"                         "UT1_Center"
# [195] "UT1_Lower"                        "UT1_Upper"
# [197] "UT2_Center"                       "UT2_Far"
# [199] "UT2_Near"                         "5pool1_2"
# [201] "Bi_0600855_T3"                    "Bi_0600906_T1"
# [203] "Bi_0600912_T1"                    "Bi_0600913_T1"
# [205] "Bi_0600915_T1_TrueTumor"          "Bi_0600916_T1"
# [207] "Bi_DFCI_0600876_T1"               "Bi_DFCI_0600890_T1"
# [209] "IpiNivo_CompleteResponse_Center"  "IpiNivo_CompleteResponse_Lateral"
# [211] "IpiNivo_CompleteResponse_Medial"  "IpiNivo_Mixed_Center"
# [213] "IpiNivo_Mixed_Far"                "IpiNivo_Mixed_Near"
# [215] "IpiNivo_Resistant_Center"         "IpiNivo_Resistant_Far"
# [217] "IpiNivo_Resistant_LymphNode"      "IpiNivo_Resistant_Near"
# [219] "NivoExposed_LowerLateral"         "NivoExposed_LowerMedial"
# [221] "NivoExposed_SupraLateral"         "Pool70-10"
# [223] "Pool70-6"                         "Pool70-8"
# [225] "Pool71-3"                         "Pool71-5"
# [227] "Pool71-6"                         "Pool71-8"
# [229] "Pool72-2"                         "Pool72-4"
# [231] "Pool73-3"                         "Pool73-4"
# [233] "Pool73-5"                         "Pool73-6"
# [235] "UT1_Center"                       "UT1_Lower"
# [237] "UT1_Upper"                        "UT2_Center"
# [239] "UT2_Far"                          "5pool1_2"
# [241] "Bi_0600855_T3"                    "Bi_0600906_T1"
# [243] "Bi_0600912_T1"                    "Bi_0600913_T1"
# [245] "Bi_0600915_T1_TrueTumor"          "Bi_0600916_T1"
# [247] "Bi_DFCI_0600876_T1"               "Bi_DFCI_0600890_T1"
# [249] "IpiNivo_CompleteResponse_Center"  "IpiNivo_CompleteResponse_Lateral"
# [251] "IpiNivo_CompleteResponse_Medial"  "IpiNivo_Mixed_Center"
# [253] "IpiNivo_Mixed_Far"                "IpiNivo_Mixed_Near"
# [255] "IpiNivo_Resistant_Center"         "IpiNivo_Resistant_Far"
# [257] "IpiNivo_Resistant_LymphNode"      "IpiNivo_Resistant_Near"
# [259] "NivoExposed_LowerLateral"         "NivoExposed_LowerMedial"
# [261] "NivoExposed_SupraLateral"         "Pool70-10"
# [263] "Pool70-6"                         "Pool70-8"
# [265] "Pool71-3"                         "Pool71-5"
# [267] "Pool71-6"                         "Pool71-8"
# [269] "Pool72-10"                        "Pool72-2"
# [271] "Pool72-4"                         "Pool73-3"
# [273] "Pool73-4"                         "Pool73-5"
# [275] "Pool73-6"                         "UT1_Center"
# [277] "UT1_Lower"                        "UT1_Upper"
# [279] "UT2_Center"                       "UT2_Far"
# [281] "UT2_Near"                         "5pool1_2"
# [283] "Bi_0600855_T3"                    "Bi_0600906_T1"
# [285] "Bi_0600912_T1"                    "Bi_0600913_T1"
# [287] "Bi_0600915_T1_TrueTumor"          "Bi_0600916_T1"
# [289] "Bi_DFCI_0600876_T1"               "Bi_DFCI_0600890_T1"
# [291] "IpiNivo_CompleteResponse_Center"  "IpiNivo_CompleteResponse_Lateral"
# [293] "IpiNivo_CompleteResponse_Medial"  "IpiNivo_Mixed_Center"
# [295] "IpiNivo_Mixed_Far"                "IpiNivo_Mixed_Near"
# [297] "IpiNivo_Resistant_Center"         "IpiNivo_Resistant_Far"
# [299] "IpiNivo_Resistant_LymphNode"      "IpiNivo_Resistant_Near"
# [301] "NivoExposed_LowerLateral"         "NivoExposed_LowerMedial"
# [303] "NivoExposed_SupraLateral"         "Pool70-10"
# [305] "Pool70-6"                         "Pool70-8"
# [307] "Pool71-3"                         "Pool71-5"
# [309] "Pool71-8"                         "Pool72-10"
# [311] "Pool72-2"                         "Pool72-4"
# [313] "Pool73-3"                         "Pool73-4"
# [315] "Pool73-5"                         "Pool73-6"
# [317] "UT1_Center"                       "UT1_Lower"
# [319] "UT1_Upper"                        "UT2_Center"
# [321] "UT2_Far"                          "UT2_Near"
# [323] "5pool1_2"                         "Bi_0600855_T3"
# [325] "Bi_0600906_T1"                    "Bi_0600912_T1"
# [327] "Bi_0600913_T1"                    "Bi_0600915_T1_TrueTumor"
# [329] "Bi_0600916_T1"                    "Bi_DFCI_0600876_T1"
# [331] "Bi_DFCI_0600890_T1"               "IpiNivo_CompleteResponse_Center"
# [333] "IpiNivo_CompleteResponse_Lateral" "IpiNivo_CompleteResponse_Medial"
# [335] "IpiNivo_Mixed_Center"             "IpiNivo_Mixed_Far"
# [337] "IpiNivo_Mixed_Near"               "IpiNivo_Resistant_Center"
# [339] "IpiNivo_Resistant_Far"            "IpiNivo_Resistant_LymphNode"
# [341] "IpiNivo_Resistant_Near"           "NivoExposed_LowerLateral"
# [343] "NivoExposed_LowerMedial"          "NivoExposed_SupraLateral"
# [345] "Pool70-10"                        "Pool70-6"
# [347] "Pool70-8"                         "Pool71-3"
# [349] "Pool71-5"                         "Pool71-8"
# [351] "Pool72-10"                        "Pool72-2"
# [353] "Pool72-4"                         "Pool73-3"
# [355] "Pool73-4"                         "Pool73-5"
# [357] "Pool73-6"                         "UT1_Center"
# [359] "UT1_Lower"                        "UT1_Upper"
# [361] "UT2_Center"                       "UT2_Far"
# [363] "UT2_Near"                         "5pool1_2"
# [365] "Bi_0600855_T3"                    "Bi_0600906_T1"
# [367] "Bi_0600912_T1"                    "Bi_0600913_T1"
# [369] "Bi_0600915_T1_TrueTumor"          "Bi_0600916_T1"
# [371] "Bi_DFCI_0600876_T1"               "Bi_DFCI_0600890_T1"
# [373] "IpiNivo_CompleteResponse_Center"  "IpiNivo_CompleteResponse_Lateral"
# [375] "IpiNivo_CompleteResponse_Medial"  "IpiNivo_Mixed_Center"
# [377] "IpiNivo_Mixed_Far"                "IpiNivo_Mixed_Near"
# [379] "IpiNivo_Resistant_Center"         "IpiNivo_Resistant_Far"
# [381] "IpiNivo_Resistant_LymphNode"      "IpiNivo_Resistant_Near"
# [383] "NivoExposed_LowerLateral"         "NivoExposed_LowerMedial"
# [385] "NivoExposed_SupraLateral"         "Pool70-10"
# [387] "Pool70-6"                         "Pool70-8"
# [389] "Pool71-3"                         "Pool71-5"
# [391] "Pool71-6"                         "Pool71-8"
# [393] "Pool72-10"                        "Pool72-2"
# [395] "Pool72-4"                         "Pool73-3"
# [397] "Pool73-4"                         "Pool73-5"
# [399] "Pool73-6"                         "UT1_Center"
# [401] "UT1_Lower"                        "UT1_Upper"
# [403] "UT2_Center"                       "UT2_Far"
# [405] "UT2_Near"                         "5pool1_2"
# [407] "Bi_0600855_T3"                    "Bi_0600906_T1"
# [409] "Bi_0600912_T1"                    "Bi_0600913_T1"
# [411] "Bi_0600915_T1_TrueTumor"          "Bi_0600916_T1"
# [413] "Bi_DFCI_0600876_T1"               "Bi_DFCI_0600890_T1"
# [415] "IpiNivo_CompleteResponse_Center"  "IpiNivo_CompleteResponse_Lateral"
# [417] "IpiNivo_CompleteResponse_Medial"  "IpiNivo_Mixed_Center"
# [419] "IpiNivo_Mixed_Far"                "IpiNivo_Mixed_Near"
# [421] "IpiNivo_Resistant_Center"         "IpiNivo_Resistant_Far"
# [423] "IpiNivo_Resistant_LymphNode"      "IpiNivo_Resistant_Near"
# [425] "NivoExposed_LowerLateral"         "NivoExposed_LowerMedial"
# [427] "NivoExposed_SupraLateral"         "Pool70-10"
# [429] "Pool70-6"                         "Pool70-8"
# [431] "Pool71-3"                         "Pool71-5"
# [433] "Pool71-8"                         "Pool72-10"
# [435] "Pool72-2"                         "Pool72-4"
# [437] "Pool73-3"                         "Pool73-4"
# [439] "Pool73-5"                         "Pool73-6"
# [441] "UT1_Center"                       "UT1_Lower"
# [443] "UT1_Upper"                        "UT2_Center"
# [445] "UT2_Far"                          "UT2_Near"
# [447] "5pool1_2"                         "Bi_0600906_T1"
# [449] "Bi_0600912_T1"                    "Bi_0600913_T1"
# [451] "Bi_0600915_T1_TrueTumor"          "Bi_0600916_T1"
# [453] "Bi_DFCI_0600876_T1"               "Bi_DFCI_0600890_T1"
# [455] "IpiNivo_CompleteResponse_Center"  "IpiNivo_CompleteResponse_Lateral"
# [457] "IpiNivo_CompleteResponse_Medial"  "IpiNivo_Mixed_Center"
# [459] "IpiNivo_Mixed_Far"                "IpiNivo_Mixed_Near"
# [461] "IpiNivo_Resistant_Center"         "IpiNivo_Resistant_Far"
# [463] "IpiNivo_Resistant_LymphNode"      "IpiNivo_Resistant_Near"
# [465] "NivoExposed_LowerLateral"         "NivoExposed_LowerMedial"
# [467] "NivoExposed_SupraLateral"         "Pool70-10"
# [469] "Pool70-6"                         "Pool70-8"
# [471] "Pool71-3"                         "Pool71-5"
# [473] "Pool71-8"                         "Pool72-2"
# [475] "Pool72-4"                         "Pool73-3"
# [477] "Pool73-4"                         "Pool73-5"
# [479] "Pool73-6"                         "UT1_Center"
# [481] "UT1_Lower"                        "UT1_Upper"
# [483] "UT2_Center"                       "UT2_Far"
# [485] "5pool1_2"                         "Bi_0600906_T1"
# [487] "Bi_0600912_T1"                    "Bi_0600913_T1"
# [489] "Bi_0600915_T1_TrueTumor"          "Bi_DFCI_0600876_T1"
# [491] "Bi_DFCI_0600890_T1"               "IpiNivo_CompleteResponse_Center"
# [493] "IpiNivo_CompleteResponse_Lateral" "IpiNivo_CompleteResponse_Medial"
# [495] "IpiNivo_Mixed_Center"             "IpiNivo_Mixed_Far"
# [497] "IpiNivo_Mixed_Near"               "IpiNivo_Resistant_Center"
# [499] "IpiNivo_Resistant_Far"            "IpiNivo_Resistant_LymphNode"
# [501] "IpiNivo_Resistant_Near"           "NivoExposed_LowerLateral"
# [503] "NivoExposed_LowerMedial"          "NivoExposed_SupraLateral"
# [505] "Pool70-10"                        "Pool70-6"
# [507] "Pool71-3"                         "Pool71-5"
# [509] "Pool71-8"                         "Pool72-2"
# [511] "Pool72-4"                         "Pool73-3"
# [513] "Pool73-4"                         "Pool73-5"
# [515] "Pool73-6"                         "UT1_Center"
# [517] "UT1_Lower"                        "UT1_Upper"
# [519] "UT2_Far"
#                               orig.ident nCount_RNA nFeature_RNA
# Tumor_5pool1_2                Tumor      10000      18069
# Tumor_Bi_0600855_T3           Tumor      10000      15019
# Tumor_Bi_0600906_T1           Tumor      10000      17420
# Tumor_Bi_0600913_T1           Tumor      10000      17015
# Tumor_Bi_0600915_T1_TrueTumor Tumor      10000      19577
# Tumor_Bi_0600916_T1           Tumor      10000       3093
#                               Sample
# Tumor_5pool1_2                5pool1_2
# Tumor_Bi_0600855_T3           Bi_0600855_T3
# Tumor_Bi_0600906_T1           Bi_0600906_T1
# Tumor_Bi_0600913_T1           Bi_0600913_T1
# Tumor_Bi_0600915_T1_TrueTumor Bi_0600915_T1_TrueTumor
# Tumor_Bi_0600916_T1           Bi_0600916_T1
#   Cohort Sample   Stage_Corrected Stage_Corrected_EarlyLate Biopsy
# 1 Braun  5pool1_2 I               Early                     Kidney
# 2 Braun  5pool1_2 I               Early                     Kidney
# 3 Braun  5pool1_2 I               Early                     Kidney
# 4 Braun  5pool1_2 I               Early                     Kidney
# 5 Braun  5pool1_2 I               Early                     Kidney
#   Cohort Sample                  Stage_Corrected Stage_Corrected_EarlyLate
# 1 Bi     Bi_0600855_T3           IV              Late
# 2 Bi     Bi_0600906_T1           IV              Late
# 3 Bi     Bi_0600912_T1           IV              Late
# 4 Bi     Bi_0600913_T1           IV              Late
# 5 Bi     Bi_0600915_T1_TrueTumor III             Late
#   Biopsy
# 1 Abdomen
# 2 Lymph_node
# 3 Lymph_node
# 4 Lung
# 5 Kidney
# [1] 519  13
#                               orig.ident nCount_RNA nFeature_RNA
# Tumor_5pool1_2                Tumor      10000      18069
# Tumor_Bi_0600855_T3           Tumor      10000      15019
# Tumor_Bi_0600906_T1           Tumor      10000      17420
# Tumor_Bi_0600913_T1           Tumor      10000      17015
# Tumor_Bi_0600915_T1_TrueTumor Tumor      10000      19577
# Tumor_Bi_0600916_T1           Tumor      10000       3093
#                               Sample
# Tumor_5pool1_2                5pool1_2
# Tumor_Bi_0600855_T3           Bi_0600855_T3
# Tumor_Bi_0600906_T1           Bi_0600906_T1
# Tumor_Bi_0600913_T1           Bi_0600913_T1
# Tumor_Bi_0600915_T1_TrueTumor Bi_0600915_T1_TrueTumor
# Tumor_Bi_0600916_T1           Bi_0600916_T1
#                               rownames                      Cohort
# Tumor_5pool1_2                Tumor_5pool1_2                Braun
# Tumor_Bi_0600855_T3           Tumor_Bi_0600855_T3           Bi
# Tumor_Bi_0600906_T1           Tumor_Bi_0600906_T1           Bi
# Tumor_Bi_0600913_T1           Tumor_Bi_0600913_T1           Bi
# Tumor_Bi_0600915_T1_TrueTumor Tumor_Bi_0600915_T1_TrueTumor Bi
# Tumor_Bi_0600916_T1           Tumor_Bi_0600916_T1           Bi
#                               Stage_Corrected Stage_Corrected_EarlyLate
# Tumor_5pool1_2                I               Early
# Tumor_Bi_0600855_T3           IV              Late
# Tumor_Bi_0600906_T1           IV              Late
# Tumor_Bi_0600913_T1           IV              Late
# Tumor_Bi_0600915_T1_TrueTumor III             Late
# Tumor_Bi_0600916_T1           IV              Late
#                               Biopsy     IO TKI Treated IO_Treated
# Tumor_5pool1_2                Kidney     No No  No      IO Naive
# Tumor_Bi_0600855_T3           Abdomen    PR Yes Yes     IO Exposed
# Tumor_Bi_0600906_T1           Lymph_node PD Yes Yes     IO Exposed
# Tumor_Bi_0600913_T1           Lung       SD Yes Yes     IO Exposed
# Tumor_Bi_0600915_T1_TrueTumor Kidney     PR No  Yes     IO Exposed
# Tumor_Bi_0600916_T1           Lymph_node No No  No      IO Naive

# %%
cluster.averages@meta.data = test
length(unique(cluster.averages$orig.ident))
length(unique(cluster.averages$Cohort))
length(unique(cluster.averages$Biopsy))
length(unique(cluster.averages$Stage_Corrected))
length(unique(cluster.averages$Stage_Corrected_EarlyLate))
length(unique(cluster.averages$Sample))
length(unique(cluster.averages$IO_Treated))
# Out:
# [1] 14
# [1] 3
# [1] 6
# [1] 4
# [1] 2
# [1] 42
# [1] 2

# %%
saveRDS(cluster.averages, file = "../Data_Objects/cluster.averages_seur_full.RDS")

# %% [markdown]
# ### Score cells for Benci/Minn IFNG.GS and ISG.RS signatures using the combined z-score method. We do this non-interactively using the following Rscript

# %% [markdown]
# ### Rscripts/seur_full_isg.rs_ifng.gs_hacksig_zscore.R

# %%
library(Seurat)
library(hacksig)
library(useful)

options(future.globals.maxSize= 100000*1024^2)

seur_full = readRDS("/broad/VanAllenLab_CA/xchip/cga_home/kevinbi/IFN_RCC_Manuscript_2024/Data_Objects/seur_full_BBK_Manuscript.RDS")
Idents(seur_full) = "BBK_Broad_Celltype"

seur_full = subset(seur_full, idents = c("Contam","Omitted"), invert = T)

benci = readRDS("/broad/VanAllenLab_CA/xchip/cga_home/kevinbi/IFN_RCC_Manuscript_2024/Signatures//Benci_Minn_ISG_Signatures.RDS")
benci$Minn_Benci_ISG.RS
benci$Minn_Benci_IFNG.GS

res = hack_sig(
  as.matrix(seur_full@assays$RNA@data),
  signatures = benci,
  method = "zscore")
head(res)

saveRDS(res, file = "/broad/VanAllenLab_CA/xchip/cga_home/kevinbi/IFN_RCC_Manuscript_2024/Figures/Figure1/seur_full_isg.rs_ifng.gs_scores_hacksig_zscore.RDS")

# %% [markdown]
# ### Read in signature scores and create a new sample/cell type average object with scores

# %%
res = data.frame(readRDS("../Figures/Figure1/seur_full_isg.rs_ifng.gs_scores_hacksig_zscore.RDS"))
row.names(res) = res$sample_id
corner(res)
# Out:
#                             sample_id                   Minn_Benci_ISG.RS
# GTTCTCGAGAGGTAGA-1.5pool1_2 GTTCTCGAGAGGTAGA-1.5pool1_2  0.03554675
# CTAGAGTCATCAGTCA-1.5pool1_2 CTAGAGTCATCAGTCA-1.5pool1_2  0.63826751
# CGGCTAGAGGTAGCCA-1.5pool1_2 CGGCTAGAGGTAGCCA-1.5pool1_2 -0.60394903
# CTGCTGTAGTGTTTGC-1.5pool1_2 CTGCTGTAGTGTTTGC-1.5pool1_2  0.18163262
# CCATGTCCATCGATGT-1.5pool1_2 CCATGTCCATCGATGT-1.5pool1_2  0.79286452
#                             Minn_Benci_IFNG.GS
# GTTCTCGAGAGGTAGA-1.5pool1_2 1.52951884
# CTAGAGTCATCAGTCA-1.5pool1_2 0.66786794
# CGGCTAGAGGTAGCCA-1.5pool1_2 0.02734308
# CTGCTGTAGTGTTTGC-1.5pool1_2 1.98420733
# CCATGTCCATCGATGT-1.5pool1_2 0.75634495

# %%
setequal(row.names(res),row.names(seur_full@meta.data))
# Out:
# [1] TRUE

# %%
seur_full@meta.data = cbind(seur_full@meta.data,res)

# %%
cluster.averages = readRDS(file = "../Data_Objects/cluster.averages_seur_full.RDS")
head(cluster.averages@meta.data)
# Out:
#                               orig.ident nCount_RNA nFeature_RNA
# Tumor_5pool1_2                Tumor      10000      18069
# Tumor_Bi_0600855_T3           Tumor      10000      15019
# Tumor_Bi_0600906_T1           Tumor      10000      17420
# Tumor_Bi_0600913_T1           Tumor      10000      17015
# Tumor_Bi_0600915_T1_TrueTumor Tumor      10000      19577
# Tumor_Bi_0600916_T1           Tumor      10000       3093
#                               Sample
# Tumor_5pool1_2                5pool1_2
# Tumor_Bi_0600855_T3           Bi_0600855_T3
# Tumor_Bi_0600906_T1           Bi_0600906_T1
# Tumor_Bi_0600913_T1           Bi_0600913_T1
# Tumor_Bi_0600915_T1_TrueTumor Bi_0600915_T1_TrueTumor
# Tumor_Bi_0600916_T1           Bi_0600916_T1
#                               rownames                      Cohort
# Tumor_5pool1_2                Tumor_5pool1_2                Braun
# Tumor_Bi_0600855_T3           Tumor_Bi_0600855_T3           Bi
# Tumor_Bi_0600906_T1           Tumor_Bi_0600906_T1           Bi
# Tumor_Bi_0600913_T1           Tumor_Bi_0600913_T1           Bi
# Tumor_Bi_0600915_T1_TrueTumor Tumor_Bi_0600915_T1_TrueTumor Bi
# Tumor_Bi_0600916_T1           Tumor_Bi_0600916_T1           Bi
#                               Stage_Corrected Stage_Corrected_EarlyLate
# Tumor_5pool1_2                I               Early
# Tumor_Bi_0600855_T3           IV              Late
# Tumor_Bi_0600906_T1           IV              Late
# Tumor_Bi_0600913_T1           IV              Late
# Tumor_Bi_0600915_T1_TrueTumor III             Late
# Tumor_Bi_0600916_T1           IV              Late
#                               Biopsy     IO TKI Treated IO_Treated
# Tumor_5pool1_2                Kidney     No No  No      IO Naive
# Tumor_Bi_0600855_T3           Abdomen    PR Yes Yes     IO Exposed
# Tumor_Bi_0600906_T1           Lymph_node PD Yes Yes     IO Exposed
# Tumor_Bi_0600913_T1           Lung       SD Yes Yes     IO Exposed
# Tumor_Bi_0600915_T1_TrueTumor Kidney     PR No  Yes     IO Exposed
# Tumor_Bi_0600916_T1           Lymph_node No No  No      IO Naive

# %% [markdown]
# ### Calculate mean and median IFNG.GS and ISG.RS scores for cell types within samples

# %%
meta = seur_full@meta.data
meta$CellType_Sample = paste(meta$BBK_Broad_Celltype,meta$Sample, sep = "_")

agg_tbl <- meta %>% group_by(CellType_Sample) %>% 
  summarise(mean_Minn_Benci_IFNG.GS=mean(Minn_Benci_IFNG.GS),
            median_Minn_Benci_IFNG.GS=median(Minn_Benci_IFNG.GS),
            mean_Minn_Benci_ISG.RS=mean(Minn_Benci_ISG.RS),
             median_Minn_Benci_ISG.RS=median(Minn_Benci_ISG.RS),
            .groups = 'drop')

# %%
head(agg_tbl)
length(intersect(agg_tbl$CellType_Sample,row.names(cluster.averages@meta.data)))

agg_tbl = data.frame(agg_tbl)
row.names(agg_tbl) = agg_tbl$CellType_Sample

agg_tbl = agg_tbl[row.names(cluster.averages@meta.data),]
head(agg_tbl)
# Out:
#   CellType_Sample                mean_Minn_Benci_IFNG.GS
# 1 B cell_5pool1_2                -1.0978988
# 2 B cell_Bi_0600906_T1           -2.5132974
# 3 B cell_Bi_0600912_T1           -0.7041632
# 4 B cell_Bi_0600913_T1           -2.1279741
# 5 B cell_Bi_0600915_T1_TrueTumor -1.7138181
# 6 B cell_Bi_0600916_T1           -1.1242947
#   median_Minn_Benci_IFNG.GS mean_Minn_Benci_ISG.RS median_Minn_Benci_ISG.RS
# 1 -1.0171722                -1.629210              -1.791840
# 2 -2.6666398                -1.886555              -2.144821
# 3 -0.8270874                -1.317441              -1.486128
# 4 -2.2004400                -1.686338              -1.844484
# 5 -1.7411677                -1.339186              -1.603440
# 6 -0.8333541                -1.320089              -1.422789
# [1] 519
#                               CellType_Sample
# Tumor_5pool1_2                Tumor_5pool1_2
# Tumor_Bi_0600855_T3           Tumor_Bi_0600855_T3
# Tumor_Bi_0600906_T1           Tumor_Bi_0600906_T1
# Tumor_Bi_0600913_T1           Tumor_Bi_0600913_T1
# Tumor_Bi_0600915_T1_TrueTumor Tumor_Bi_0600915_T1_TrueTumor
# Tumor_Bi_0600916_T1           Tumor_Bi_0600916_T1
#                               mean_Minn_Benci_IFNG.GS median_Minn_Benci_IFNG.GS
# Tumor_5pool1_2                -0.1068307               0.001524774
# Tumor_Bi_0600855_T3            1.4230100               1.466193830
# Tumor_Bi_0600906_T1           -3.3066950              -3.252330049
# Tumor_Bi_0600913_T1           -1.9655722              -2.067969281
# Tumor_Bi_0600915_T1_TrueTumor  0.7061117               0.399946097
# Tumor_Bi_0600916_T1           -3.0532609              -3.273836432
#                               mean_Minn_Benci_ISG.RS median_Minn_Benci_ISG.RS
# Tumor_5pool1_2                -0.6592034             -0.7462525
# Tumor_Bi_0600855_T3            2.5565679              1.6597896
# Tumor_Bi_0600906_T1           -0.4697834             -0.4647894
# Tumor_Bi_0600913_T1           -0.3313105             -0.6590700
# Tumor_Bi_0600915_T1_TrueTumor  2.4009610              2.5194925
# Tumor_Bi_0600916_T1           -1.5374262             -1.6437121

# %%
cluster.averages$mean_Minn_Benci_IFNG.GS = agg_tbl$mean_Minn_Benci_IFNG.GS
cluster.averages$median_Minn_Benci_IFNG.GS = agg_tbl$median_Minn_Benci_IFNG.GS
cluster.averages$mean_Minn_Benci_ISG.RS = agg_tbl$mean_Minn_Benci_ISG.RS
cluster.averages$median_Minn_Benci_ISG.RS = agg_tbl$median_Minn_Benci_ISG.RS

# %%
cytosig_mat = as.matrix(data.frame(t(scale(cluster.averages@meta.data[,c("mean_Minn_Benci_IFNG.GS","median_Minn_Benci_IFNG.GS","mean_Minn_Benci_ISG.RS","median_Minn_Benci_ISG.RS")])), check.names = F))
length(intersect(colnames(cytosig_mat), row.names(cluster.averages@meta.data)))
setdiff(colnames(cytosig_mat), row.names(cluster.averages@meta.data))
setdiff(row.names(cluster.averages@meta.data),colnames(cytosig_mat))
# Out:
# [1] 519
# character(0)
# character(0)

# %%
cluster.averages@assays$RNA@data = cytosig_mat
cluster.averages@assays$RNA@scale.data = cytosig_mat
corner(cluster.averages@assays$RNA@scale.data)
# Out:
#                           Tumor_5pool1_2 Tumor_Bi_0600855_T3
# mean_Minn_Benci_IFNG.GS   -0.002713241   0.8202813
# median_Minn_Benci_IFNG.GS  0.104647326   0.8968624
# mean_Minn_Benci_ISG.RS    -0.536215844   1.4139705
# median_Minn_Benci_ISG.RS  -0.478661607   1.0128355
#                           Tumor_Bi_0600906_T1 Tumor_Bi_0600913_T1
# mean_Minn_Benci_IFNG.GS   -1.7241152          -1.0026436
# median_Minn_Benci_IFNG.GS -1.6553084          -1.0147075
# mean_Minn_Benci_ISG.RS    -0.4213432          -0.3373670
# median_Minn_Benci_ISG.RS  -0.3041836          -0.4246175
#                           Tumor_Bi_0600915_T1_TrueTumor
# mean_Minn_Benci_IFNG.GS   0.4346180
# median_Minn_Benci_IFNG.GS 0.3201468
# mean_Minn_Benci_ISG.RS    1.3196036
# median_Minn_Benci_ISG.RS  1.5457625

# %%
saveRDS(cluster.averages, file = "../Data_Objects/cluster.averages_seur_full_benci_minn_ISG_hacksig_zscore.RDS")

# %% [markdown]
# ### Make heatmaps of median IFNG.GS and ISG.RS scores

# %% [markdown]
# ### Annotation with biopsy site

# %%
cluster.averages$orig.ident = factor(cluster.averages$orig.ident, levels = c("Tumor","Fibroblast","Perivascular cell","Endothelial","TAM","Monocyte","DC","CD8","CD8 NK-like","NK","T-Helper","T-reg","B cell","Plasma cell"))

options(repr.plot.width=17, repr.plot.height=4)
colors <- list(celltype_cols[levels(cluster.averages$orig.ident)],c("#FCF9CF","#A3D6B4","#41B6C3","#2560AA"),c("#252525","#f7f7f7"),brewer.pal(6, "Set2"),c("#E11F28","#292562","#50AF48"))

DefaultAssay(cluster.averages) = "RNA"
plot_heatmap(dataset = cluster.averages, 
              markers = c("median_Minn_Benci_ISG.RS","median_Minn_Benci_IFNG.GS"),
              sort_var = c("orig.ident","Stage_Corrected","IO_Treated","Biopsy","Cohort"),
              anno_var = c("orig.ident","Stage_Corrected","IO_Treated","Biopsy","Cohort"),
              anno_colors = colors,hm_colors = c("#F900F9","black","#F6F600"))

#magma = c("#000004","#b73779","#fcfdbf")
#seur_approx = c("purple","black","yellow")
#seur = c("#F900F9","black","#F6F600")
# Out:
# plot without title

# %% [markdown]
# ### Annotation without biopsy site

# %%
cluster.averages$orig.ident = factor(cluster.averages$orig.ident, levels = c("Tumor","Fibroblast","Perivascular cell","Endothelial","TAM","Monocyte","DC","CD8","CD8 NK-like","NK","T-Helper","T-reg","B cell","Plasma cell"))

options(repr.plot.width=17, repr.plot.height=4)
colors <- list(celltype_cols[levels(cluster.averages$orig.ident)],c("#FCF9CF","#A3D6B4","#41B6C3","#2560AA"),c("#252525","#f7f7f7"),c("#E11F28","#292562","#50AF48"))

DefaultAssay(cluster.averages) = "RNA"
plot_heatmap(dataset = cluster.averages, 
              markers = c("median_Minn_Benci_ISG.RS","median_Minn_Benci_IFNG.GS"),
              sort_var = c("orig.ident","Stage_Corrected","IO_Treated","Cohort"),
              anno_var = c("orig.ident","Stage_Corrected","IO_Treated","Cohort"),
              anno_colors = colors,hm_colors = c("#F900F9","black","#F6F600"))

#magma = c("#000004","#b73779","#fcfdbf")
#seur_approx = c("purple","black","yellow")
#seur = c("#F900F9","black","#F6F600")
# Out:
# plot without title

# %% [markdown]
# ### Export

# %%
pdf("../Figures/Figure1/Figure1D_RS_GS_Heatmap.pdf", useDingbats = F, width = 17, height = 4)

cluster.averages$orig.ident = factor(cluster.averages$orig.ident, levels = c("Tumor","Fibroblast","Perivascular cell","Endothelial","TAM","Monocyte","DC","CD8","CD8 NK-like","NK","T-Helper","T-reg","B cell","Plasma cell"))

options(repr.plot.width=17, repr.plot.height=4)
colors <- list(celltype_cols[levels(cluster.averages$orig.ident)],c("#FCF9CF","#A3D6B4","#41B6C3","#2560AA"),c("#252525","#f7f7f7"),c("#E11F28","#292562","#50AF48"))

DefaultAssay(cluster.averages) = "RNA"
plot_heatmap(dataset = cluster.averages, 
              markers = c("median_Minn_Benci_ISG.RS","median_Minn_Benci_IFNG.GS"),
              sort_var = c("orig.ident","Stage_Corrected","IO_Treated","Cohort"),
              anno_var = c("orig.ident","Stage_Corrected","IO_Treated","Cohort"),
              anno_colors = colors,hm_colors = c("#F900F9","black","#F6F600"))

dev.off()
# Out:
# png
#   2

# %% [markdown]
# ### Violin plots for IFNG.GS and ISG.RS scores in broad lineages (tumor, stromal, myeloid, lymphoid)

# %%
table(seur_full$BBK_Broad_Celltype)
# Out:
#             Tumor        Fibroblast Perivascular cell       Endothelial
#             18994               277              1691              1781
#               TAM          Monocyte                DC               CD8
#             27684             15072              4522             88457
#       CD8 NK-like                NK          T-Helper             T-reg
#             13563             20422             22656              8618
#            B cell       Plasma cell
#              3330              1304

# %% [markdown]
# ### Group broad cell types into lineages

# %%
temp_meta = seur_full@meta.data
temp_meta = mutate(temp_meta, Lineage = ifelse(BBK_Broad_Celltype == "Tumor","Tumor",ifelse(BBK_Broad_Celltype %in% c("Fibroblast","Perivascular cell","Endothelial"),"Stromal",ifelse(BBK_Broad_Celltype %in% c("TAM","Monocyte","DC"),"Myeloid",ifelse(BBK_Broad_Celltype %in% c("CD8","CD8 NK-like","NK","T-Helper","T-reg","B cell","Plasma cell"),"Lymphoid","Other")))))
temp_meta$Lineage = factor(temp_meta$Lineage, levels = c("Tumor","Stromal","Myeloid","Lymphoid"))

seur_full$Lineage = temp_meta$Lineage
table(seur_full$Lineage)
# Out:
#    Tumor  Stromal  Myeloid Lymphoid
#    18994     3749    47278   158350

# %%
seur_full_vln = seur_full@meta.data
seur_full_vln = seur_full_vln[,c("Lineage","Minn_Benci_ISG.RS","Minn_Benci_IFNG.GS","SampleName")]
seur_full_vln$Lineage = factor(seur_full_vln$Lineage, levels = c("Tumor","Stromal","Myeloid","Lymphoid"))
seur_full_vln$SampleName = factor(seur_full_vln$SampleName)

head(seur_full_vln)
# Out:
#                             Lineage Minn_Benci_ISG.RS Minn_Benci_IFNG.GS
# GTTCTCGAGAGGTAGA-1.5pool1_2 Tumor    0.03554675        1.52951884
# CTAGAGTCATCAGTCA-1.5pool1_2 Tumor    0.63826751        0.66786794
# CGGCTAGAGGTAGCCA-1.5pool1_2 Tumor   -0.60394903        0.02734308
# CTGCTGTAGTGTTTGC-1.5pool1_2 Tumor    0.18163262        1.98420733
# CCATGTCCATCGATGT-1.5pool1_2 Tumor    0.79286452        0.75634495
# TCTGAGAAGCGTAATA-1.5pool1_2 Tumor   -0.47836038       -0.23387518
#                             SampleName
# GTTCTCGAGAGGTAGA-1.5pool1_2 S1_T
# CTAGAGTCATCAGTCA-1.5pool1_2 S1_T
# CGGCTAGAGGTAGCCA-1.5pool1_2 S1_T
# CTGCTGTAGTGTTTGC-1.5pool1_2 S1_T
# CCATGTCCATCGATGT-1.5pool1_2 S1_T
# TCTGAGAAGCGTAATA-1.5pool1_2 S1_T

# %% [markdown]
# ### Calculate mean and median IFNG.GS and ISG.RS scores for lineages within samples

# %%
collapsed_vln = seur_full_vln%>%
group_by(Lineage, SampleName)%>% 
summarise(Minn_Benci_ISG.RS_Mean=mean(Minn_Benci_ISG.RS), Minn_Benci_ISG.RS_Median=median(Minn_Benci_ISG.RS),Minn_Benci_IFNG.GS_Mean=mean(Minn_Benci_IFNG.GS), Minn_Benci_IFNG.GS_Median=median(Minn_Benci_IFNG.GS))
          
          head(collapsed_vln)
# Out:
# `summarise()` has grouped output by 'Lineage'. You can override using the
# `.groups` argument.
#   Lineage SampleName                  Minn_Benci_ISG.RS_Mean
# 1 Tumor   IpiNivo_Mixed_Center        1.7133341
# 2 Tumor   IpiNivo_Mixed_Far           1.2157927
# 3 Tumor   IpiNivo_Mixed_Near          1.2094532
# 4 Tumor   IpiNivo_Resistant_Center    0.3675125
# 5 Tumor   IpiNivo_Resistant_Far       0.6372577
# 6 Tumor   IpiNivo_Resistant_LymphNode 0.5069080
#   Minn_Benci_ISG.RS_Median Minn_Benci_IFNG.GS_Mean Minn_Benci_IFNG.GS_Median
# 1 1.7568095                 0.58002764             -0.2239729
# 2 0.9992034                -0.08527523             -0.6923863
# 3 1.2052281                -1.02556638             -1.2586783
# 4 0.3337374                -0.76149567             -0.7000803
# 5 0.5522860                -0.39657861             -0.3479200
# 6 0.4512845                -0.65296960             -0.5933253

# %% [markdown]
# ### Note that a bug in geom_signif shuffles the color orders, so we manually adjust

# %%
options(repr.plot.width=7, repr.plot.height=6)

ggplot(collapsed_vln, aes(x=Lineage, y=Minn_Benci_ISG.RS_Median,fill = Lineage)) + 
  geom_violin(trim=FALSE,scale = 'width')+
geom_boxplot(width=0.35, fill="white", outlier.shape = NA) +
geom_jitter(width = 0.1,alpha = 0.6,shape = 21,size = 2.5) +
labs(title = "Minn_Benci_ISG.RS", x = "Lineage" , y = "AUCell Score") +
scale_fill_manual(values = c("#A0BAAC","#e6ab02","#d95f02","#1b9e77")) +
#scale_y_continuous(breaks=seq(0.0, 0.5, 0.1)) + 
theme_classic(base_size = 14) +
geom_signif(comparisons = list(c(1,2),c(2,3),c(2,4)),map_signif_level=TRUE,step_increase = 0.02)

ggsave("../Figures/Figure1/Figure1D_RS_Violins_Collapsed.pdf",width = 7, height = 6)
# Out:
# plot without title

# %%
options(repr.plot.width=7, repr.plot.height=6)

ggplot(collapsed_vln, aes(x=Lineage, y=Minn_Benci_IFNG.GS_Median,fill = Lineage)) + 
  geom_violin(trim=FALSE,scale = 'width')+
geom_boxplot(width=0.35, fill="white", outlier.shape = NA) +
geom_jitter(width = 0.1,alpha = 0.6,shape = 21,size = 2.5) +
labs(title = "Minn_Benci_IFNG.GS", x = "Lineage" , y = "AUCell Score") +
scale_fill_manual(values = c("#A0BAAC","#e6ab02","#1b9e77","#d95f02")) +
#scale_y_continuous(breaks=seq(0.0, 0.4, 0.1)) + 
theme_classic(base_size = 14) +
geom_signif(comparisons = list(c(1,3),c(2,3),c(3,4)),map_signif_level=TRUE,step_increase = 0.02)

ggsave("../Figures/Figure1/Figure1D_GS_Violins_Collapsed.pdf",width = 7, height = 6)
# Out:
# plot without title

# %% [markdown]
# ### Figure 1E. Heatmap of differentially expressed putative ISGs across broad cell types <a name="3"></a>

# %% [markdown]
# ### Run DE between each cell type and all other cell types in our searchspace of putative ISGs using the following Rscript

# %% [markdown]
# ### Rscripts/seur_full_goi_FindAllMarkers_LR_Patient_Stage_Corrected_EarlyLate.R

# %%
library(Seurat)
library(useful)
library(dplyr)

seur_full = readRDS("/broad/VanAllenLab_CA/xchip/cga_home/kevinbi/IFN_RCC_Manuscript_2024/Data_Objects/seur_full_BBK_Manuscript.RDS")

seur_full$BBK_Broad_Celltype = factor(seur_full$BBK_Broad_Celltype, levels = c("Tumor","Fibroblast","Perivascular cell","Endothelial","TAM","Monocyte","DC","CD8","CD8 NK-like","NK","T-Helper","T-reg","B cell","Plasma cell","Contam","Omitted"))
Idents(seur_full) = "BBK_Broad_Celltype"

seur_full = subset(seur_full, idents = c("Contam","Omitted"), invert = T)
table(seur_full$Stage_Corrected_EarlyLate)

goi = readRDS("/broad/VanAllenLab_CA/xchip/cga_home/kevinbi/IFN_RCC_Manuscript_2024/Signatures/manuscript_goi_hallmark_benciminn_curated.RDS")
length(goi)

markers = FindAllMarkers(seur_full, only.pos = TRUE, min.pct = 0, logfc.threshold = 0, features = intersect(row.names(seur_full),goi),verbose = T, assay = "RNA",test.use = "LR",latent.vars = c("Patient","Stage_Corrected_EarlyLate"))

markers %>% group_by(cluster) %>% top_n(n = 10, wt = avg_log2FC)

saveRDS(markers, file = "/broad/VanAllenLab_CA/xchip/cga_home/kevinbi/IFN_RCC_Manuscript_2024/Figures/Figure1/Figure1E_seur_full_goi_FindAllMarkers_LR_Patient_Stage_Corrected_EarlyLate.RDS")

# %%
cluster.averages = readRDS(file = "../Data_Objects/cluster.averages_seur_full.RDS")
head(cluster.averages@meta.data)
# Out:
#                               orig.ident nCount_RNA nFeature_RNA
# Tumor_5pool1_2                Tumor      10000      18069
# Tumor_Bi_0600855_T3           Tumor      10000      15019
# Tumor_Bi_0600906_T1           Tumor      10000      17420
# Tumor_Bi_0600913_T1           Tumor      10000      17015
# Tumor_Bi_0600915_T1_TrueTumor Tumor      10000      19577
# Tumor_Bi_0600916_T1           Tumor      10000       3093
#                               Sample
# Tumor_5pool1_2                5pool1_2
# Tumor_Bi_0600855_T3           Bi_0600855_T3
# Tumor_Bi_0600906_T1           Bi_0600906_T1
# Tumor_Bi_0600913_T1           Bi_0600913_T1
# Tumor_Bi_0600915_T1_TrueTumor Bi_0600915_T1_TrueTumor
# Tumor_Bi_0600916_T1           Bi_0600916_T1
#                               rownames                      Cohort
# Tumor_5pool1_2                Tumor_5pool1_2                Braun
# Tumor_Bi_0600855_T3           Tumor_Bi_0600855_T3           Bi
# Tumor_Bi_0600906_T1           Tumor_Bi_0600906_T1           Bi
# Tumor_Bi_0600913_T1           Tumor_Bi_0600913_T1           Bi
# Tumor_Bi_0600915_T1_TrueTumor Tumor_Bi_0600915_T1_TrueTumor Bi
# Tumor_Bi_0600916_T1           Tumor_Bi_0600916_T1           Bi
#                               Stage_Corrected Stage_Corrected_EarlyLate
# Tumor_5pool1_2                I               Early
# Tumor_Bi_0600855_T3           IV              Late
# Tumor_Bi_0600906_T1           IV              Late
# Tumor_Bi_0600913_T1           IV              Late
# Tumor_Bi_0600915_T1_TrueTumor III             Late
# Tumor_Bi_0600916_T1           IV              Late
#                               Biopsy     IO TKI Treated IO_Treated
# Tumor_5pool1_2                Kidney     No No  No      IO Naive
# Tumor_Bi_0600855_T3           Abdomen    PR Yes Yes     IO Exposed
# Tumor_Bi_0600906_T1           Lymph_node PD Yes Yes     IO Exposed
# Tumor_Bi_0600913_T1           Lung       SD Yes Yes     IO Exposed
# Tumor_Bi_0600915_T1_TrueTumor Kidney     PR No  Yes     IO Exposed
# Tumor_Bi_0600916_T1           Lymph_node No No  No      IO Naive

# %%
ifn.markers = readRDS("../Figures/Figure1/Figure1E_seur_full_goi_FindAllMarkers_LR_Patient_Stage_Corrected_EarlyLate.RDS")
ifn.markers %>%
    subset(p_val_adj < 0.05) %>%
    group_by(cluster) %>%
    top_n(n = 15, wt = avg_log2FC) -> top15

top15
# Out:
#     p_val         avg_log2FC pct.1 pct.2 p_val_adj     cluster     gene
# 1    0.000000e+00 2.1614390  0.857 0.341  0.000000e+00 Tumor       IFITM3
# 2    0.000000e+00 2.0622319  0.677 0.005  0.000000e+00 Tumor       C1S
# 3    0.000000e+00 1.8140818  0.714 0.096  0.000000e+00 Tumor       SERPING1
# 4    0.000000e+00 1.7600203  0.813 0.537  0.000000e+00 Tumor       MT2A
# 5    0.000000e+00 1.6924070  0.527 0.040  0.000000e+00 Tumor       IFI27
# 6    0.000000e+00 1.6477334  0.676 0.225  0.000000e+00 Tumor       SOD2
# 7    0.000000e+00 1.5919156  0.638 0.119  0.000000e+00 Tumor       LGALS3BP
# 8    0.000000e+00 1.4991780  0.522 0.007  0.000000e+00 Tumor       C1R
# 9    0.000000e+00 1.4345796  0.677 0.102  0.000000e+00 Tumor       PFKP
# 10   0.000000e+00 1.1764546  0.597 0.234  0.000000e+00 Tumor       TNFSF10
# 11   0.000000e+00 1.1451466  0.224 0.017  0.000000e+00 Tumor       CCL2
# 12   0.000000e+00 0.8309583  0.771 0.630  0.000000e+00 Tumor       LY6E
# 13   0.000000e+00 0.7763012  0.665 0.330  0.000000e+00 Tumor       LGALS3
# 14   0.000000e+00 0.7161712  0.419 0.036  0.000000e+00 Tumor       SSPN
# 15   0.000000e+00 0.7108795  0.359 0.005  0.000000e+00 Tumor       CFB
# 16  1.997247e-265 2.8942831  0.975 0.383 7.912892e-261 Fibroblast  IFITM3
# 17  5.762898e-220 2.9124167  0.823 0.025 2.283203e-215 Fibroblast  TIMP3
# 18  1.494687e-214 2.9516337  0.888 0.146 5.921802e-210 Fibroblast  SERPING1
# 19  1.619354e-172 2.4853569  0.704 0.060 6.415718e-168 Fibroblast  C1S
# 20  1.612921e-163 2.0962174  0.542 0.049 6.390233e-159 Fibroblast  C1R
# 21  1.653021e-130 1.6540367  0.495 0.034 6.549105e-126 Fibroblast  CFH
# 22  2.124301e-109 1.7378003  0.805 0.161 8.416269e-105 Fibroblast  LGALS3BP
# 23  4.652665e-101 1.3183777  0.942 0.618  1.843339e-96 Fibroblast  IFITM2
# 24   1.912771e-77 1.7800257  0.910 0.560  7.578207e-73 Fibroblast  MT2A
# 25   2.809962e-69 1.3733282  0.610 0.209  1.113279e-64 Fibroblast  MTHFD2
# 26   5.523640e-62 1.0858674  0.697 0.249  2.188411e-57 Fibroblast  ARID5B
# 27   9.816144e-53 1.0180251  0.310 0.041  3.889058e-48 Fibroblast  PROCR
# 28   3.289810e-30 1.2674136  0.350 0.057  1.303390e-25 Fibroblast  THBS1
# 29   4.187215e-12 0.9290060  0.505 0.234  1.658933e-07 Fibroblast  CDKN1A
# 30   3.914583e-10 1.1389585  0.296 0.080  1.550919e-05 Fibroblast  IFI27
# ... ...           ...        ...   ...   ...           ...         ...
# 175 8.219497e-232 0.57000765 0.399 0.276 3.256482e-227 T-reg       CASP1
# 176 2.257926e-205 0.53779661 0.360 0.209 8.945678e-201 T-reg       PIM1
# 177 1.367493e-142 0.49346784 0.617 0.484 5.417869e-138 T-reg       LCP2
# 178 2.000373e-122 0.42219363 0.258 0.183 7.925277e-118 T-reg       EPSTI1
# 179  9.166421e-90 0.53260173 0.426 0.345  3.631645e-85 T-reg       STAT1
# 180  1.269710e-59 0.41880168 0.392 0.308  5.030463e-55 T-reg       ISG15
# 181  0.000000e+00 2.38131825 0.612 0.011  0.000000e+00 B cell      BANK1
# 182  0.000000e+00 1.59778378 0.516 0.132  0.000000e+00 B cell      SELL
# 183  0.000000e+00 1.57627625 0.468 0.108  0.000000e+00 B cell      IRF8
# 184  0.000000e+00 1.49941739 0.434 0.112  0.000000e+00 B cell      MARCH1
# 185  0.000000e+00 1.07927411 0.327 0.099  0.000000e+00 B cell      CD40
# 186  0.000000e+00 0.94383826 0.996 0.883  0.000000e+00 B cell      CD74
# 187  0.000000e+00 0.88476017 0.985 0.503  0.000000e+00 B cell      HLA-DRA
# 188 4.168686e-190 0.69837723 0.455 0.327 1.651592e-185 B cell      SP110
# 189 1.040131e-163 0.69192191 0.159 0.066 4.120893e-159 B cell      SSPN
# 190 1.324027e-163 0.59421939 0.184 0.096 5.245661e-159 B cell      CIITA
# 191 9.190292e-119 0.50483224 0.231 0.141 3.641102e-114 B cell      NCOA3
# 192  6.842378e-75 0.53997057 0.349 0.248  2.710882e-70 B cell      ARID5B
# 193  1.627213e-70 0.46047596 0.522 0.397  6.446854e-66 B cell      ISG20
# 194  1.176062e-65 0.68849255 0.570 0.440  4.659438e-61 B cell      CD69
# 195  6.965023e-54 0.51065941 0.120 0.100  2.759473e-49 B cell      IL4R
# 196 8.070111e-164 0.73626520 0.594 0.135 3.197297e-159 Plasma cell CD38
# 197 1.322394e-116 0.74810188 0.803 0.397 5.239193e-112 Plasma cell ISG20
# 198  1.012983e-98 0.48390871 0.536 0.102  4.013339e-94 Plasma cell SLAMF7
# 199  1.933053e-69 0.45864927 0.282 0.040  7.658562e-65 Plasma cell IRF4
# 200  2.375372e-62 0.38128031 0.418 0.084  9.410987e-58 Plasma cell ZBP1
# 201  4.784824e-30 0.21745654 0.334 0.069  1.895699e-25 Plasma cell IFNAR2
# 202  1.810884e-12 0.24484199 0.390 0.234  7.174540e-08 Plasma cell CDKN1A
# 203  4.995047e-08 0.10378929 0.238 0.169  1.978988e-03 Plasma cell PELI1
# 204  5.543088e-08 0.07839432 0.086 0.024  2.196116e-03 Plasma cell CSF2RB

# %%
ifn.markers = readRDS("../Figures/Figure1/Figure1E_seur_full_goi_FindAllMarkers_LR_Patient_Stage_Corrected_EarlyLate.RDS")
ifn.markers %>%
    subset(p_val_adj < 0.05) %>%
    group_by(cluster) %>%
    top_n(n = 4, wt = avg_log2FC) -> top4

top4
# Out:
#    p_val         avg_log2FC pct.1 pct.2 p_val_adj     cluster
# 1   0.000000e+00 2.1614390  0.857 0.341  0.000000e+00 Tumor
# 2   0.000000e+00 2.0622319  0.677 0.005  0.000000e+00 Tumor
# 3   0.000000e+00 1.8140818  0.714 0.096  0.000000e+00 Tumor
# 4   0.000000e+00 1.7600203  0.813 0.537  0.000000e+00 Tumor
# 5  1.997247e-265 2.8942831  0.975 0.383 7.912892e-261 Fibroblast
# 6  5.762898e-220 2.9124167  0.823 0.025 2.283203e-215 Fibroblast
# 7  1.494687e-214 2.9516337  0.888 0.146 5.921802e-210 Fibroblast
# 8  1.619354e-172 2.4853569  0.704 0.060 6.415718e-168 Fibroblast
# 9   0.000000e+00 2.9409828  0.999 0.379  0.000000e+00 Perivascular cell
# 10  0.000000e+00 2.6908443  0.938 0.141  0.000000e+00 Perivascular cell
# 11  0.000000e+00 2.2790112  0.798 0.230  0.000000e+00 Perivascular cell
# 12  0.000000e+00 2.2131965  0.978 0.557  0.000000e+00 Perivascular cell
# 13  0.000000e+00 4.1088380  0.866 0.019  0.000000e+00 Endothelial
# 14  0.000000e+00 3.3841067  0.937 0.074  0.000000e+00 Endothelial
# 15  0.000000e+00 3.1737966  0.997 0.379  0.000000e+00 Endothelial
# 16  0.000000e+00 2.0543692  0.568 0.134  0.000000e+00 Endothelial
# 17  0.000000e+00 3.4901170  0.999 0.443  0.000000e+00 TAM
# 18  0.000000e+00 2.8014837  0.998 0.606  0.000000e+00 TAM
# 19  0.000000e+00 2.7587828  1.000 0.869  0.000000e+00 TAM
# 20  0.000000e+00 2.6260022  0.965 0.349  0.000000e+00 TAM
# 21  0.000000e+00 2.3753074  0.378 0.034  0.000000e+00 Monocyte
# 22  0.000000e+00 1.6692832  0.647 0.090  0.000000e+00 Monocyte
# 23  0.000000e+00 1.6500945  0.699 0.190  0.000000e+00 Monocyte
# 24  0.000000e+00 1.6079363  0.829 0.352  0.000000e+00 Monocyte
# 25  0.000000e+00 2.5115256  0.999 0.501  0.000000e+00 DC
# 26  0.000000e+00 2.5004681  0.988 0.412  0.000000e+00 DC
# 27  0.000000e+00 2.1226118  1.000 0.883  0.000000e+00 DC
# 28  0.000000e+00 2.0501400  0.997 0.647  0.000000e+00 DC
# 29  0.000000e+00 2.2253491  0.969 0.348  0.000000e+00 CD8
# 30  0.000000e+00 1.8526962  0.902 0.293  0.000000e+00 CD8
# 31  0.000000e+00 1.4981729  0.395 0.073  0.000000e+00 CD8
# 32  0.000000e+00 0.9175318  0.993 0.975  0.000000e+00 CD8
# 33  0.000000e+00 1.0422766  0.875 0.519  0.000000e+00 CD8 NK-like
# 34  0.000000e+00 0.7117536  0.989 0.563  0.000000e+00 CD8 NK-like
# 35  0.000000e+00 0.6846342  0.797 0.607  0.000000e+00 CD8 NK-like
# 36  0.000000e+00 0.6413030  0.601 0.386  0.000000e+00 CD8 NK-like
# 37  0.000000e+00 1.6973710  0.627 0.166  0.000000e+00 NK
# 38  0.000000e+00 1.6297909  0.342 0.090  0.000000e+00 NK
# 39  0.000000e+00 1.6271269  0.914 0.504  0.000000e+00 NK
# 40  0.000000e+00 1.3439108  0.876 0.593  0.000000e+00 NK
# 41  0.000000e+00 1.0817016  0.710 0.413  0.000000e+00 T-Helper
# 42  0.000000e+00 0.9093570  0.274 0.122  0.000000e+00 T-Helper
# 43  0.000000e+00 0.8857489  0.617 0.464  0.000000e+00 T-Helper
# 44  0.000000e+00 0.8771905  0.957 0.887  0.000000e+00 T-Helper
# 45  0.000000e+00 1.1231198  0.434 0.125  0.000000e+00 T-reg
# 46  0.000000e+00 1.0416710  0.551 0.294  0.000000e+00 T-reg
# 47  0.000000e+00 0.9590453  0.495 0.240  0.000000e+00 T-reg
# 48  0.000000e+00 0.8624013  0.644 0.389  0.000000e+00 T-reg
# 49  0.000000e+00 2.3813182  0.612 0.011  0.000000e+00 B cell
# 50  0.000000e+00 1.5977838  0.516 0.132  0.000000e+00 B cell
# 51  0.000000e+00 1.5762762  0.468 0.108  0.000000e+00 B cell
# 52  0.000000e+00 1.4994174  0.434 0.112  0.000000e+00 B cell
# 53 8.070111e-164 0.7362652  0.594 0.135 3.197297e-159 Plasma cell
# 54 1.322394e-116 0.7481019  0.803 0.397 5.239193e-112 Plasma cell
# 55  1.012983e-98 0.4839087  0.536 0.102  4.013339e-94 Plasma cell
# 56  1.933053e-69 0.4586493  0.282 0.040  7.658562e-65 Plasma cell
#    gene
# 1  IFITM3
# 2  C1S
# 3  SERPING1
# 4  MT2A
# 5  IFITM3
# 6  TIMP3
# 7  SERPING1
# 8  C1S
# 9  IFITM3
# 10 SERPING1
# 11 CDKN1A
# 12 MT2A
# 13 TIMP3
# 14 IFI27
# 15 IFITM3
# 16 SOCS3
# 17 HLA-DRA
# 18 HLA-DRB1
# 19 CD74
# 20 HLA-DQA1
# 21 THBS1
# 22 FPR1
# 23 NAMPT
# 24 IFITM3
# 25 HLA-DRA
# 26 HLA-DQA1
# 27 CD74
# 28 HLA-DRB1
# 29 CCL5
# 30 GZMA
# 31 VCAM1
# 32 HLA-A
# 33 IFITM1
# 34 CCL5
# 35 IFITM2
# 36 ISG20
# 37 IL2RB
# 38 XCL1
# 39 IFITM1
# 40 IFITM2
# 41 CD69
# 42 SELL
# 43 TNFAIP3
# 44 BTG1
# 45 SELL
# 46 GBP2
# 47 ARID5B
# 48 ISG20
# 49 BANK1
# 50 SELL
# 51 IRF8
# 52 MARCH1
# 53 CD38
# 54 ISG20
# 55 SLAMF7
# 56 IRF4

# %% [markdown]
# ### Top 4 genes per cluster (unique)

# %%
cluster.averages$orig.ident = factor(cluster.averages$orig.ident, levels = c("Tumor","Fibroblast","Perivascular cell","Endothelial","TAM","Monocyte","DC","CD8","CD8 NK-like","NK","T-Helper","T-reg","B cell","Plasma cell"))

options(repr.plot.width=12, repr.plot.height=12)
colors <- list(celltype_cols[levels(cluster.averages$orig.ident)],c("#FCF9CF","#A3D6B4","#41B6C3","#2560AA"),c("#252525","#f7f7f7"),c("#E11F28","#292562","#50AF48"))

DefaultAssay(cluster.averages) = "RNA"
plot_heatmap(dataset = cluster.averages, 
              markers = unique(top4$gene),
              sort_var = c("orig.ident","Stage_Corrected","IO_Treated","Cohort"),
              anno_var = c("orig.ident","Stage_Corrected","IO_Treated","Cohort"),
              anno_colors = colors)
# Out:
# plot without title

# %% [markdown]
# ### Top 15 genes per cluster (unique)

# %%
cluster.averages$orig.ident = factor(cluster.averages$orig.ident, levels = c("Tumor","Fibroblast","Perivascular cell","Endothelial","TAM","Monocyte","DC","CD8","CD8 NK-like","NK","T-Helper","T-reg","B cell","Plasma cell"))

options(repr.plot.width=12, repr.plot.height=12)
colors <- list(celltype_cols[levels(cluster.averages$orig.ident)],c("#FCF9CF","#A3D6B4","#41B6C3","#2560AA"),c("#252525","#f7f7f7"),c("#E11F28","#292562","#50AF48"))

DefaultAssay(cluster.averages) = "RNA"
plot_heatmap(dataset = cluster.averages, 
              markers = unique(top15$gene),
              sort_var = c("orig.ident","Stage_Corrected","IO_Treated","Cohort"),
              anno_var = c("orig.ident","Stage_Corrected","IO_Treated","Cohort"),
              anno_colors = colors)
# Out:
# plot without title

# %%
subset(top15,cluster == "Tumor")
# Out:
#    p_val avg_log2FC pct.1 pct.2 p_val_adj cluster gene
# 1  0     2.1614390  0.857 0.341 0         Tumor   IFITM3
# 2  0     2.0622319  0.677 0.005 0         Tumor   C1S
# 3  0     1.8140818  0.714 0.096 0         Tumor   SERPING1
# 4  0     1.7600203  0.813 0.537 0         Tumor   MT2A
# 5  0     1.6924070  0.527 0.040 0         Tumor   IFI27
# 6  0     1.6477334  0.676 0.225 0         Tumor   SOD2
# 7  0     1.5919156  0.638 0.119 0         Tumor   LGALS3BP
# 8  0     1.4991780  0.522 0.007 0         Tumor   C1R
# 9  0     1.4345796  0.677 0.102 0         Tumor   PFKP
# 10 0     1.1764546  0.597 0.234 0         Tumor   TNFSF10
# 11 0     1.1451466  0.224 0.017 0         Tumor   CCL2
# 12 0     0.8309583  0.771 0.630 0         Tumor   LY6E
# 13 0     0.7763012  0.665 0.330 0         Tumor   LGALS3
# 14 0     0.7161712  0.419 0.036 0         Tumor   SSPN
# 15 0     0.7108795  0.359 0.005 0         Tumor   CFB

# %% [markdown]
# ### Export top 4 heatmap

# %%
pdf("../Figures/Figure1/Figure1E_DE_Heatmap_Top4.pdf", width = 12, height = 12, useDingbats = F)

cluster.averages$orig.ident = factor(cluster.averages$orig.ident, levels = c("Tumor","Fibroblast","Perivascular cell","Endothelial","TAM","Monocyte","DC","CD8","CD8 NK-like","NK","T-Helper","T-reg","B cell","Plasma cell"))

options(repr.plot.width=12, repr.plot.height=12)
colors <- list(celltype_cols[levels(cluster.averages$orig.ident)],c("#FCF9CF","#A3D6B4","#41B6C3","#2560AA"),c("#252525","#f7f7f7"),c("#E11F28","#292562","#50AF48"))

DefaultAssay(cluster.averages) = "RNA"
plot_heatmap(dataset = cluster.averages, 
              markers = unique(top4$gene),
              sort_var = c("orig.ident","Stage_Corrected","IO_Treated","Cohort"),
              anno_var = c("orig.ident","Stage_Corrected","IO_Treated","Cohort"),
              anno_colors = colors)

dev.off()
# Out:
# png
#   2

# %% [markdown]
# ### Export top 15

# %%
pdf("../Figures/Figure1/Figure1E_DE_Heatmap_Top15.pdf", width = 12, height = 14, useDingbats = F)

cluster.averages$orig.ident = factor(cluster.averages$orig.ident, levels = c("Tumor","Fibroblast","Perivascular cell","Endothelial","TAM","Monocyte","DC","CD8","CD8 NK-like","NK","T-Helper","T-reg","B cell","Plasma cell"))

options(repr.plot.width=12, repr.plot.height=12)
colors <- list(celltype_cols[levels(cluster.averages$orig.ident)],c("#FCF9CF","#A3D6B4","#41B6C3","#2560AA"),c("#252525","#f7f7f7"),c("#E11F28","#292562","#50AF48"))

DefaultAssay(cluster.averages) = "RNA"
plot_heatmap(dataset = cluster.averages, 
              markers = unique(top15$gene),
              sort_var = c("orig.ident","Stage_Corrected","IO_Treated","Cohort"),
              anno_var = c("orig.ident","Stage_Corrected","IO_Treated","Cohort"),
              anno_colors = colors)

dev.off()
# Out:
# png
#   2

# %% [markdown]
# ### Figure 1F. Lollipop plots showing top IFN1 and IFNG skewed ISGs for Tumor, TAM, and CD8s  <a name="4"></a>

# %% [markdown]
# ### Tumor cells

# %%
Tumor = readRDS("../Outputs/Manuscript_MixedEffects_Output_Stage_Corrected_EarlyLate/Tumor_CytoSig_MixedEffects_Patient_Stage_Corrected_EarlyLate_Vargenes.RDS")
Tumor = subset(Tumor, gene %in% goi)
head(Tumor)

Tumor = Tumor[,c("IFN1_resp_beta","IFNG_resp_beta")]
colnames(Tumor) = c("IFN1","IFNG")
head(Tumor)
# Out:
#       IFN1_resp_beta IFNG_resp_beta IFN1_resp_pval IFNG_resp_pval gene
# ADAR   0.41903190    0.070665285    4.783141e-217   9.181300e-08  ADAR
# B2M    0.02888296    0.119257407     3.223055e-02   2.517324e-18  B2M
# BATF2  0.24158159    0.063870946     6.396052e-52   6.942798e-05  BATF2
# BST2   0.28714067    0.005398415    1.866317e-107   6.794404e-01  BST2
# C1S   -0.12175930    0.420618639     6.628705e-18  4.719658e-185  C1S
# CASP1  0.05748864    0.096352403     3.594579e-04   3.476535e-09  CASP1
#       IFN1_resp_p_adj_BH IFNG_resp_p_adj_BH IFN1_resp_p_adj_Bonf
# ADAR  1.843901e-214       1.111851e-06      4.425362e-213
# B2M    9.243554e-02       8.200804e-17       1.000000e+00
# BATF2  4.167343e-50       5.379797e-04       5.917627e-48
# BST2  3.453433e-105       8.351511e-01      1.726716e-103
# C1S    1.327463e-16      1.091657e-181       6.132878e-14
# CASP1  1.835378e-03       5.017925e-08       1.000000e+00
#       IFNG_resp_p_adj_Bonf
# ADAR   8.494539e-04
# B2M    2.329028e-14
# BATF2  6.423477e-01
# BST2   1.000000e+00
# C1S   4.366628e-181
# CASP1  3.216490e-05
#       IFN1        IFNG
# ADAR   0.41903190 0.070665285
# B2M    0.02888296 0.119257407
# BATF2  0.24158159 0.063870946
# BST2   0.28714067 0.005398415
# C1S   -0.12175930 0.420618639
# CASP1  0.05748864 0.096352403

# %%
tum_ifn_df = Tumor
tum_ifn_df$IFNG_minus_IFN1 = tum_ifn_df$IFNG - tum_ifn_df$IFN1
tum_ifn_df$IFN1_minus_IFNG = tum_ifn_df$IFN1 - tum_ifn_df$IFNG
head(tum_ifn_df)

(tum_ifn_df %>% arrange(desc(IFNG)))[1:15,]
(tum_ifn_df %>% arrange(desc(IFN1)))[1:15,]

tum_IFNG_UP = (subset(tum_ifn_df, IFNG > 0) %>% arrange(desc(IFNG_minus_IFN1)))[1:15,]
tum_IFNG_UP = tum_IFNG_UP %>% arrange(desc(IFNG))
tum_IFNG_UP

tum_IFN1_UP = (subset(tum_ifn_df, IFN1 > 0) %>% arrange(desc(IFN1_minus_IFNG)))[1:15,]
tum_IFN1_UP = tum_IFN1_UP %>% arrange(desc(IFN1))
tum_IFN1_UP
# Out:
#       IFN1        IFNG        IFNG_minus_IFN1 IFN1_minus_IFNG
# ADAR   0.41903190 0.070665285 -0.34836662      0.34836662
# B2M    0.02888296 0.119257407  0.09037445     -0.09037445
# BATF2  0.24158159 0.063870946 -0.17771064      0.17771064
# BST2   0.28714067 0.005398415 -0.28174226      0.28174226
# C1S   -0.12175930 0.420618639  0.54237794     -0.54237794
# CASP1  0.05748864 0.096352403  0.03886376     -0.03886376
#        IFN1        IFNG      IFNG_minus_IFN1 IFN1_minus_IFNG
# IRF1   -0.42244641 0.8281361 1.2505825       -1.2505825
# GBP2   -0.51914992 0.7686943 1.2878443       -1.2878443
# C1S    -0.12175930 0.4206186 0.5423779       -0.5423779
# PSMB10 -0.13144551 0.4098876 0.5413331       -0.5413331
# WARS   -0.18847759 0.3693951 0.5578727       -0.5578727
# VAMP5  -0.10184986 0.3676143 0.4694641       -0.4694641
# GBP4   -0.03262070 0.3620081 0.3946288       -0.3946288
# STAT1   0.14560403 0.3598428 0.2142388       -0.2142388
# IL18BP -0.04453638 0.3313285 0.3758649       -0.3758649
# IL15RA -0.09993292 0.3207403 0.4206732       -0.4206732
# LAP3   -0.01390626 0.2792082 0.2931144       -0.2931144
# CXCL10 -0.10193481 0.2670015 0.3689363       -0.3689363
# PSMB8  -0.08565573 0.2626391 0.3482949       -0.3482949
# CD74   -0.01417077 0.2615176 0.2756884       -0.2756884
# SOD2   -0.01182666 0.2502393 0.2620660       -0.2620660
#         IFN1      IFNG        IFNG_minus_IFN1 IFN1_minus_IFNG
# IFI6    0.8783609 -0.35210941 -1.2304703      1.2304703
# MX1     0.7082904 -0.01125910 -0.7195495      0.7195495
# ISG15   0.7028615 -0.01051459 -0.7133761      0.7133761
# IFIT1   0.7006323  0.01933312 -0.6812992      0.6812992
# IFIT3   0.6861503  0.13382031 -0.5523300      0.5523300
# IFIT2   0.6476945  0.13896951 -0.5087250      0.5087250
# OASL    0.6465628  0.07320975 -0.5733530      0.5733530
# OAS1    0.6287095 -0.04248120 -0.6711907      0.6711907
# EIF2AK2 0.6240618 -0.14206225 -0.7661241      0.7661241
# RSAD2   0.6168298  0.08978470 -0.5270451      0.5270451
# MX2     0.5898627  0.08949625 -0.5003664      0.5003664
# DDX58   0.5859331 -0.04901068 -0.6349438      0.6349438
# IRF7    0.5729972 -0.05459064 -0.6275878      0.6275878
# OAS3    0.5557788 -0.00571949 -0.5614983      0.5614983
# LY6E    0.5272881 -0.22391338 -0.7512015      0.7512015
#        IFN1        IFNG      IFNG_minus_IFN1 IFN1_minus_IFNG
# IRF1   -0.42244641 0.8281361 1.2505825       -1.2505825
# GBP2   -0.51914992 0.7686943 1.2878443       -1.2878443
# C1S    -0.12175930 0.4206186 0.5423779       -0.5423779
# PSMB10 -0.13144551 0.4098876 0.5413331       -0.5413331
# WARS   -0.18847759 0.3693951 0.5578727       -0.5578727
# VAMP5  -0.10184986 0.3676143 0.4694641       -0.4694641
# GBP4   -0.03262070 0.3620081 0.3946288       -0.3946288
# IL18BP -0.04453638 0.3313285 0.3758649       -0.3758649
# IL15RA -0.09993292 0.3207403 0.4206732       -0.4206732
# LAP3   -0.01390626 0.2792082 0.2931144       -0.2931144
# CXCL10 -0.10193481 0.2670015 0.3689363       -0.3689363
# PSMB8  -0.08565573 0.2626391 0.3482949       -0.3482949
# CD74   -0.01417077 0.2615176 0.2756884       -0.2756884
# SOD2   -0.01182666 0.2502393 0.2620660       -0.2620660
# TRAFD1 -0.05907102 0.2492818 0.3083528       -0.3083528
#         IFN1      IFNG        IFNG_minus_IFN1 IFN1_minus_IFNG
# IFI6    0.8783609 -0.35210941 -1.2304703      1.2304703
# MX1     0.7082904 -0.01125910 -0.7195495      0.7195495
# ISG15   0.7028615 -0.01051459 -0.7133761      0.7133761
# IFIT1   0.7006323  0.01933312 -0.6812992      0.6812992
# IFIT3   0.6861503  0.13382031 -0.5523300      0.5523300
# IFIT2   0.6476945  0.13896951 -0.5087250      0.5087250
# OASL    0.6465628  0.07320975 -0.5733530      0.5733530
# OAS1    0.6287095 -0.04248120 -0.6711907      0.6711907
# EIF2AK2 0.6240618 -0.14206225 -0.7661241      0.7661241
# RSAD2   0.6168298  0.08978470 -0.5270451      0.5270451
# DDX58   0.5859331 -0.04901068 -0.6349438      0.6349438
# IRF7    0.5729972 -0.05459064 -0.6275878      0.6275878
# OAS3    0.5557788 -0.00571949 -0.5614983      0.5614983
# LY6E    0.5272881 -0.22391338 -0.7512015      0.7512015
# OAS2    0.5217188  0.01465715 -0.5070617      0.5070617

# %%
options(repr.plot.width=3.8, repr.plot.height=10)

library(reshape2)
tum_IFN1_UP$gene = factor(row.names(tum_IFN1_UP), levels = rev(row.names(tum_IFN1_UP)))
tum_IFN1_UP_melt = melt(tum_IFN1_UP[,c("IFNG","IFN1","gene")])
#tum_IFN1_UP_melt$same = rep("same",nrow(tum_IFN1_UP_melt))
head(tum_IFN1_UP_melt)

IFN1_plot = ggplot(tum_IFN1_UP_melt) +
    geom_hline(lty = 2, yintercept = 0,color = "black") +
  geom_segment( aes(x=gene, xend=gene, y=0, yend=value), color="gray50") +
  geom_point( aes(x=gene, y=value, color=variable), size=4 ) +
  coord_flip()+scale_color_manual(values = c("#009444","#ff7f00")) +
scale_y_continuous(limits = c(-0.6,0.9),breaks = seq(-0.6, 0.9, by = 0.3)) +
  theme_pubr(base_size = 14) +

  xlab("") +
  ylab("Beta coef of CytoSig score") 

library(reshape2)
tum_IFNG_UP$gene = factor(row.names(tum_IFNG_UP), levels = rev(row.names(tum_IFNG_UP)))
tum_IFNG_UP_melt = melt(tum_IFNG_UP[,c("IFNG","IFN1","gene")])
#tum_IFNG_UP_melt$same = rep("same",nrow(tum_IFNG_UP_melt))
head(tum_IFNG_UP_melt)

IFNG_plot = ggplot(tum_IFNG_UP_melt) +
    geom_hline(lty = 2, yintercept = 0,color = "black") +
  geom_segment( aes(x=gene, xend=gene, y=0, yend=value), color="gray50") +
  geom_point( aes(x=gene, y=value, color=variable), size=4 ) +
  coord_flip()+scale_color_manual(values = c("#009444","#ff7f00")) +
scale_y_continuous(limits = c(-0.6,0.9),breaks = seq(-0.6, 0.9, by = 0.3)) +
  theme_pubr(base_size = 14) +

  xlab("") +
  ylab("Beta coef of CytoSig score") 

plot_grid(IFN1_plot, IFNG_plot, ncol = 1,align = "v")

ggsave("../Figures/Figure1/Figure1F_Tumor_MixedEffects_Lollipops.pdf",width = 3.8, height = 10)
# Out:
# Using gene as id variables
#   gene  variable value
# 1 IFI6  IFNG     -0.35210941
# 2 MX1   IFNG     -0.01125910
# 3 ISG15 IFNG     -0.01051459
# 4 IFIT1 IFNG      0.01933312
# 5 IFIT3 IFNG      0.13382031
# 6 IFIT2 IFNG      0.13896951
# Using gene as id variables
#   gene   variable value
# 1 IRF1   IFNG     0.8281361
# 2 GBP2   IFNG     0.7686943
# 3 C1S    IFNG     0.4206186
# 4 PSMB10 IFNG     0.4098876
# 5 WARS   IFNG     0.3693951
# 6 VAMP5  IFNG     0.3676143
# plot without title

# %% [markdown]
# ### TAM

# %%
TAM = readRDS("../Outputs/Manuscript_MixedEffects_Output_Stage_Corrected_EarlyLate/TAM_CytoSig_MixedEffects_Patient_Stage_Corrected_EarlyLate_Vargenes.RDS")
TAM = subset(TAM, gene %in% goi)
head(TAM)

TAM = TAM[,c("IFN1_resp_beta","IFNG_resp_beta")]
colnames(TAM) = c("IFN1","IFNG")
head(TAM)
# Out:
#       IFN1_resp_beta IFNG_resp_beta IFN1_resp_pval IFNG_resp_pval gene
# ADAR   0.275490658   0.041760669    2.201738e-81   6.210763e-04   ADAR
# B2M    0.113953100   0.116549646    1.098039e-23   1.828289e-33   B2M
# BATF2  0.104352640   0.059003099    1.211776e-13   1.329105e-06   BATF2
# BST2   0.225430471   0.061373771    1.176541e-59   1.723637e-07   BST2
# C1S   -0.008487081   0.007627021    5.431116e-01   5.420873e-01   C1S
# CASP1  0.049163361   0.166839814    5.586026e-04   2.345456e-41   CASP1
#       IFN1_resp_p_adj_BH IFNG_resp_p_adj_BH IFN1_resp_p_adj_Bonf
# ADAR  2.550951e-79       3.914197e-03       2.015251e-77
# B2M   4.778087e-22       8.807542e-32       1.005035e-19
# BATF2 3.281475e-12       1.306692e-05       1.109139e-09
# BST2  1.035469e-57       1.847053e-06       1.076888e-55
# C1S   8.052720e-01       7.622944e-01       1.000000e+00
# CASP1 4.823481e-03       1.376151e-39       1.000000e+00
#       IFNG_resp_p_adj_Bonf
# ADAR  1.000000e+00
# B2M   1.673433e-29
# BATF2 1.216530e-02
# BST2  1.577645e-03
# C1S   1.000000e+00
# CASP1 2.146796e-37
#       IFN1         IFNG
# ADAR   0.275490658 0.041760669
# B2M    0.113953100 0.116549646
# BATF2  0.104352640 0.059003099
# BST2   0.225430471 0.061373771
# C1S   -0.008487081 0.007627021
# CASP1  0.049163361 0.166839814

# %%
tam_ifn_df = TAM
tam_ifn_df$IFNG_minus_IFN1 = tam_ifn_df$IFNG - tam_ifn_df$IFN1
tam_ifn_df$IFN1_minus_IFNG = tam_ifn_df$IFN1 - tam_ifn_df$IFNG
head(tam_ifn_df)

(tam_ifn_df %>% arrange(desc(IFNG)))[1:15,]
(tam_ifn_df %>% arrange(desc(IFN1)))[1:15,]

tam_IFNG_UP = (subset(tam_ifn_df, IFNG > 0) %>% arrange(desc(IFNG_minus_IFN1)))[1:15,]
tam_IFNG_UP = tam_IFNG_UP %>% arrange(desc(IFNG))
tam_IFNG_UP

tam_IFN1_UP = (subset(tam_ifn_df, IFN1 > 0) %>% arrange(desc(IFN1_minus_IFNG)))[1:15,]
tam_IFN1_UP = tam_IFN1_UP %>% arrange(desc(IFN1))
tam_IFN1_UP
# Out:
#       IFN1         IFNG        IFNG_minus_IFN1 IFN1_minus_IFNG
# ADAR   0.275490658 0.041760669 -0.233729990     0.233729990
# B2M    0.113953100 0.116549646  0.002596546    -0.002596546
# BATF2  0.104352640 0.059003099 -0.045349540     0.045349540
# BST2   0.225430471 0.061373771 -0.164056701     0.164056701
# C1S   -0.008487081 0.007627021  0.016114101    -0.016114101
# CASP1  0.049163361 0.166839814  0.117676453    -0.117676453
#        IFN1         IFNG      IFNG_minus_IFN1 IFN1_minus_IFNG
# IRF1   -0.406411703 0.7581929 1.1646046       -1.1646046
# GBP2   -0.414991690 0.7404038 1.1553955       -1.1553955
# VAMP5  -0.137019190 0.5718050 0.7088242       -0.7088242
# STAT1   0.086556241 0.5391702 0.4526140       -0.4526140
# GBP4   -0.041550665 0.5254908 0.5670415       -0.5670415
# WARS   -0.055247038 0.4823088 0.5375558       -0.5375558
# CXCL10  0.112355515 0.4754871 0.3631315       -0.3631315
# TAP1   -0.040873426 0.4717982 0.5126716       -0.5126716
# LAP3    0.071941274 0.4630551 0.3911138       -0.3911138
# CXCL9  -0.152022366 0.4579882 0.6100106       -0.6100106
# PSMB10 -0.148476197 0.4096598 0.5581360       -0.5581360
# PSMB9   0.004277061 0.4005034 0.3962264       -0.3962264
# PSME2   0.001385678 0.3735672 0.3721815       -0.3721815
# CXCL11 -0.030120613 0.3596217 0.3897424       -0.3897424
# PSMB8  -0.023817417 0.3279812 0.3517986       -0.3517986
#         IFN1      IFNG         IFNG_minus_IFN1 IFN1_minus_IFNG
# IFI6    0.7629987 -0.235933410 -0.9989321      0.9989321
# IFIT3   0.7217419  0.019958398 -0.7017836      0.7017836
# IFIT1   0.6939211 -0.110228447 -0.8041495      0.8041495
# IFIT2   0.6638361  0.058728965 -0.6051071      0.6051071
# ISG15   0.6188748 -0.052219522 -0.6710943      0.6710943
# MX1     0.6151728 -0.034627400 -0.6498002      0.6498002
# EIF2AK2 0.5635555 -0.173285832 -0.7368414      0.7368414
# LY6E    0.5634476 -0.052935684 -0.6163832      0.6163832
# RSAD2   0.5393801 -0.002193011 -0.5415731      0.5415731
# IFI44L  0.5252176 -0.011766979 -0.5369846      0.5369846
# IRF7    0.5145131  0.022096742 -0.4924163      0.4924163
# MX2     0.5095782 -0.060013063 -0.5695913      0.5695913
# IFITM1  0.4980944  0.022140172 -0.4759542      0.4759542
# OAS3    0.4973943 -0.031366094 -0.5287604      0.5287604
# OASL    0.4815383 -0.065687987 -0.5472263      0.5472263
#          IFN1         IFNG      IFNG_minus_IFN1 IFN1_minus_IFNG
# IRF1     -0.406411703 0.7581929 1.1646046       -1.1646046
# GBP2     -0.414991690 0.7404038 1.1553955       -1.1553955
# VAMP5    -0.137019190 0.5718050 0.7088242       -0.7088242
# STAT1     0.086556241 0.5391702 0.4526140       -0.4526140
# GBP4     -0.041550665 0.5254908 0.5670415       -0.5670415
# WARS     -0.055247038 0.4823088 0.5375558       -0.5375558
# TAP1     -0.040873426 0.4717982 0.5126716       -0.5126716
# LAP3      0.071941274 0.4630551 0.3911138       -0.3911138
# CXCL9    -0.152022366 0.4579882 0.6100106       -0.6100106
# PSMB10   -0.148476197 0.4096598 0.5581360       -0.5581360
# PSMB9     0.004277061 0.4005034 0.3962264       -0.3962264
# CXCL11   -0.030120613 0.3596217 0.3897424       -0.3897424
# SLAMF7   -0.137933140 0.3157349 0.4536681       -0.4536681
# RIPK2    -0.166424449 0.2316392 0.3980637       -0.3980637
# HLA-DQA1 -0.206463786 0.1824890 0.3889528       -0.3889528
#         IFN1      IFNG         IFNG_minus_IFN1 IFN1_minus_IFNG
# IFI6    0.7629987 -0.235933410 -0.9989321      0.9989321
# IFIT3   0.7217419  0.019958398 -0.7017836      0.7017836
# IFIT1   0.6939211 -0.110228447 -0.8041495      0.8041495
# IFIT2   0.6638361  0.058728965 -0.6051071      0.6051071
# ISG15   0.6188748 -0.052219522 -0.6710943      0.6710943
# MX1     0.6151728 -0.034627400 -0.6498002      0.6498002
# EIF2AK2 0.5635555 -0.173285832 -0.7368414      0.7368414
# LY6E    0.5634476 -0.052935684 -0.6163832      0.6163832
# RSAD2   0.5393801 -0.002193011 -0.5415731      0.5415731
# IFI44L  0.5252176 -0.011766979 -0.5369846      0.5369846
# MX2     0.5095782 -0.060013063 -0.5695913      0.5695913
# OAS3    0.4973943 -0.031366094 -0.5287604      0.5287604
# OASL    0.4815383 -0.065687987 -0.5472263      0.5472263
# DDX58   0.4595472 -0.058108262 -0.5176555      0.5176555
# USP18   0.4474134 -0.070414271 -0.5178277      0.5178277

# %%
options(repr.plot.width=3.8, repr.plot.height=10)

library(reshape2)
tam_IFN1_UP$gene = factor(row.names(tam_IFN1_UP), levels = rev(row.names(tam_IFN1_UP)))
tam_IFN1_UP_melt = melt(tam_IFN1_UP[,c("IFNG","IFN1","gene")])
#tam_IFN1_UP_melt$same = rep("same",nrow(tam_IFN1_UP_melt))
head(tam_IFN1_UP_melt)

IFN1_plot = ggplot(tam_IFN1_UP_melt) +
    geom_hline(lty = 2, yintercept = 0,color = "black") +
  geom_segment( aes(x=gene, xend=gene, y=0, yend=value), color="gray50") +
  geom_point( aes(x=gene, y=value, color=variable), size=4 ) +
  coord_flip()+scale_color_manual(values = c("#009444","#ff7f00")) +
scale_y_continuous(limits = c(-0.6,0.9),breaks = seq(-0.6, 0.9, by = 0.3)) +
  theme_pubr(base_size = 14) +

  xlab("") +
  ylab("Beta coef of CytoSig score") 

library(reshape2)
tam_IFNG_UP$gene = factor(row.names(tam_IFNG_UP), levels = rev(row.names(tam_IFNG_UP)))
tam_IFNG_UP_melt = melt(tam_IFNG_UP[,c("IFNG","IFN1","gene")])
#tam_IFNG_UP_melt$same = rep("same",nrow(tam_IFNG_UP_melt))
head(tam_IFNG_UP_melt)

IFNG_plot = ggplot(tam_IFNG_UP_melt) +
    geom_hline(lty = 2, yintercept = 0,color = "black") +
  geom_segment( aes(x=gene, xend=gene, y=0, yend=value), color="gray50") +
  geom_point( aes(x=gene, y=value, color=variable), size=4 ) +
  coord_flip()+scale_color_manual(values = c("#009444","#ff7f00")) +
scale_y_continuous(limits = c(-0.6,0.9),breaks = seq(-0.6, 0.9, by = 0.3)) +
  theme_pubr(base_size = 14) +

  xlab("") +
  ylab("Beta coef of CytoSig score") 

plot_grid(IFN1_plot, IFNG_plot, ncol = 1,align = "v")

ggsave("../Figures/Figure1/Figure1F_TAM_MixedEffects_Lollipops.pdf",width = 3.8, height = 10)
# Out:
# Using gene as id variables
#   gene  variable value
# 1 IFI6  IFNG     -0.23593341
# 2 IFIT3 IFNG      0.01995840
# 3 IFIT1 IFNG     -0.11022845
# 4 IFIT2 IFNG      0.05872896
# 5 ISG15 IFNG     -0.05221952
# 6 MX1   IFNG     -0.03462740
# Using gene as id variables
#   gene  variable value
# 1 IRF1  IFNG     0.7581929
# 2 GBP2  IFNG     0.7404038
# 3 VAMP5 IFNG     0.5718050
# 4 STAT1 IFNG     0.5391702
# 5 GBP4  IFNG     0.5254908
# 6 WARS  IFNG     0.4823088
# plot without title

# %% [markdown]
# ### CD8s

# %%
CD8 = readRDS("../Outputs/Manuscript_MixedEffects_Output_Stage_Corrected_EarlyLate/CD8_CytoSig_MixedEffects_Patient_Stage_Corrected_EarlyLate_Vargenes.RDS")
CD8 = subset(CD8, gene %in% goi)
head(CD8)

CD8 = CD8[,c("IFN1_resp_beta","IFNG_resp_beta")]
colnames(CD8) = c("IFN1","IFNG")
head(CD8)
# Out:
#       IFN1_resp_beta IFNG_resp_beta IFN1_resp_pval IFNG_resp_pval gene
# ADAR  0.1801965886    0.035868766   1.706146e-252  3.359685e-12   ADAR
# B2M   0.0279836375    0.055705100    2.397273e-08  4.956225e-30   B2M
# BATF2 0.0129252391   -0.003395494    1.501051e-02  5.198141e-01   BATF2
# BST2  0.1280709167    0.033972641   3.223270e-133  2.119968e-11   BST2
# C1S   0.0001387948   -0.006650631    9.796434e-01  2.106106e-01   C1S
# CASP1 0.0582374649    0.036748151    2.566352e-27  2.517833e-12   CASP1
#       IFN1_resp_p_adj_BH IFNG_resp_p_adj_BH IFN1_resp_p_adj_Bonf
# ADAR  4.263468e-250      5.891565e-11       1.534848e-248
# B2M    3.810225e-07      2.933303e-28        2.156587e-04
# BATF2  7.976050e-02      7.476868e-01        1.000000e+00
# BST2  4.327841e-131      3.486514e-10       2.899654e-129
# C1S    9.930436e-01      4.537003e-01        1.000000e+00
# CASP1  1.068838e-25      4.458745e-11        2.308690e-23
#       IFNG_resp_p_adj_Bonf
# ADAR  3.022373e-08
# B2M   4.458620e-26
# BATF2 1.000000e+00
# BST2  1.907123e-07
# C1S   1.000000e+00
# CASP1 2.265043e-08
#       IFN1         IFNG
# ADAR  0.1801965886  0.035868766
# B2M   0.0279836375  0.055705100
# BATF2 0.0129252391 -0.003395494
# BST2  0.1280709167  0.033972641
# C1S   0.0001387948 -0.006650631
# CASP1 0.0582374649  0.036748151

# %%
cd8_ifn_df = CD8
cd8_ifn_df$IFNG_minus_IFN1 = cd8_ifn_df$IFNG - cd8_ifn_df$IFN1
cd8_ifn_df$IFN1_minus_IFNG = cd8_ifn_df$IFN1 - cd8_ifn_df$IFNG
head(cd8_ifn_df)

(cd8_ifn_df %>% arrange(desc(IFNG)))[1:15,]
(cd8_ifn_df %>% arrange(desc(IFN1)))[1:15,]

cd8_IFNG_UP = (subset(cd8_ifn_df, IFNG > 0) %>% arrange(desc(IFNG_minus_IFN1)))[1:15,]
cd8_IFNG_UP = cd8_IFNG_UP %>% arrange(desc(IFNG))
cd8_IFNG_UP

cd8_IFN1_UP = (subset(cd8_ifn_df, IFN1 > 0) %>% arrange(desc(IFN1_minus_IFNG)))[1:15,]
cd8_IFN1_UP = cd8_IFN1_UP %>% arrange(desc(IFN1))
cd8_IFN1_UP
# Out:
#       IFN1         IFNG         IFNG_minus_IFN1 IFN1_minus_IFNG
# ADAR  0.1801965886  0.035868766 -0.144327822     0.144327822
# B2M   0.0279836375  0.055705100  0.027721463    -0.027721463
# BATF2 0.0129252391 -0.003395494 -0.016320733     0.016320733
# BST2  0.1280709167  0.033972641 -0.094098276     0.094098276
# C1S   0.0001387948 -0.006650631 -0.006789425     0.006789425
# CASP1 0.0582374649  0.036748151 -0.021489314     0.021489314
#        IFN1         IFNG       IFNG_minus_IFN1 IFN1_minus_IFNG
# IRF1   -0.325117250 0.68380970  1.008926951    -1.008926951
# GBP2   -0.224469760 0.43597420  0.660443963    -0.660443963
# STAT1   0.238464077 0.30400040  0.065536324    -0.065536324
# PSMB10 -0.086231021 0.28431013  0.370541146    -0.370541146
# VAMP5  -0.108834136 0.25787999  0.366714126    -0.366714126
# PSMB8   0.035542999 0.20140639  0.165863394    -0.165863394
# TRAFD1  0.036684142 0.16063692  0.123952775    -0.123952775
# CCL5   -0.025039602 0.14344333  0.168482927    -0.168482927
# CD38    0.153205602 0.12635796 -0.026847638     0.026847638
# GZMA   -0.021538275 0.12628728  0.147825552    -0.147825552
# GBP4    0.076353548 0.12512458  0.048771028    -0.048771028
# LAP3    0.127096830 0.12319868 -0.003898153     0.003898153
# CASP4  -0.037946482 0.11289970  0.150846187    -0.150846187
# TAPBP  -0.009433791 0.10004453  0.109478319    -0.109478319
# RBCK1   0.092904115 0.09800547  0.005101359    -0.005101359
#         IFN1      IFNG         IFNG_minus_IFN1 IFN1_minus_IFNG
# IFI6    0.6751853 -0.145293570 -0.8204789      0.8204789
# IFIT3   0.4719807  0.042402272 -0.4295784      0.4295784
# IFIT1   0.4072397  0.019937084 -0.3873026      0.3873026
# IRF7    0.4028441 -0.027315006 -0.4301592      0.4301592
# IFI44L  0.3995537  0.003438403 -0.3961153      0.3961153
# EIF2AK2 0.3954885 -0.073542436 -0.4690309      0.4690309
# RSAD2   0.3667486  0.023798709 -0.3429499      0.3429499
# IFIT2   0.3663848  0.035425997 -0.3309588      0.3309588
# MX1     0.3610914  0.029328731 -0.3317627      0.3317627
# ISG15   0.3376965  0.035880148 -0.3018163      0.3018163
# OAS1    0.3369678  0.021481932 -0.3154858      0.3154858
# LY6E    0.3321990 -0.025379329 -0.3575783      0.3575783
# PLSCR1  0.3271513 -0.012172232 -0.3393236      0.3393236
# DDX58   0.3016314 -0.039226982 -0.3408584      0.3408584
# CMPK2   0.2571029  0.016608507 -0.2404944      0.2404944
#        IFN1         IFNG       IFNG_minus_IFN1 IFN1_minus_IFNG
# IRF1   -0.325117250 0.68380970 1.00892695      -1.00892695
# GBP2   -0.224469760 0.43597420 0.66044396      -0.66044396
# PSMB10 -0.086231021 0.28431013 0.37054115      -0.37054115
# VAMP5  -0.108834136 0.25787999 0.36671413      -0.36671413
# PSMB8   0.035542999 0.20140639 0.16586339      -0.16586339
# TRAFD1  0.036684142 0.16063692 0.12395277      -0.12395277
# CCL5   -0.025039602 0.14344333 0.16848293      -0.16848293
# GZMA   -0.021538275 0.12628728 0.14782555      -0.14782555
# CASP4  -0.037946482 0.11289970 0.15084619      -0.15084619
# TAPBP  -0.009433791 0.10004453 0.10947832      -0.10947832
# ARID5B -0.066120608 0.09709756 0.16321817      -0.16321817
# MCL1    0.012503938 0.09208624 0.07958230      -0.07958230
# HLA-E   0.004947756 0.08618001 0.08123225      -0.08123225
# PIM1   -0.025132858 0.05291853 0.07805138      -0.07805138
# SOCS3  -0.043952099 0.03546111 0.07941320      -0.07941320
#         IFN1      IFNG         IFNG_minus_IFN1 IFN1_minus_IFNG
# IFI6    0.6751853 -0.145293570 -0.8204789      0.8204789
# IFIT3   0.4719807  0.042402272 -0.4295784      0.4295784
# IFIT1   0.4072397  0.019937084 -0.3873026      0.3873026
# IRF7    0.4028441 -0.027315006 -0.4301592      0.4301592
# IFI44L  0.3995537  0.003438403 -0.3961153      0.3961153
# EIF2AK2 0.3954885 -0.073542436 -0.4690309      0.4690309
# RSAD2   0.3667486  0.023798709 -0.3429499      0.3429499
# IFIT2   0.3663848  0.035425997 -0.3309588      0.3309588
# MX1     0.3610914  0.029328731 -0.3317627      0.3317627
# ISG15   0.3376965  0.035880148 -0.3018163      0.3018163
# OAS1    0.3369678  0.021481932 -0.3154858      0.3154858
# LY6E    0.3321990 -0.025379329 -0.3575783      0.3575783
# PLSCR1  0.3271513 -0.012172232 -0.3393236      0.3393236
# DDX58   0.3016314 -0.039226982 -0.3408584      0.3408584
# OAS3    0.2478762  0.005702303 -0.2421739      0.2421739

# %%
options(repr.plot.width=3.8, repr.plot.height=10)

library(reshape2)
cd8_IFN1_UP$gene = factor(row.names(cd8_IFN1_UP), levels = rev(row.names(cd8_IFN1_UP)))
cd8_IFN1_UP_melt = melt(cd8_IFN1_UP[,c("IFNG","IFN1","gene")])
#cd8_IFN1_UP_melt$same = rep("same",nrow(cd8_IFN1_UP_melt))
head(cd8_IFN1_UP_melt)

IFN1_plot = ggplot(cd8_IFN1_UP_melt) +
    geom_hline(lty = 2, yintercept = 0,color = "black") +
  geom_segment( aes(x=gene, xend=gene, y=0, yend=value), color="gray50") +
  geom_point( aes(x=gene, y=value, color=variable), size=4 ) +
  coord_flip()+scale_color_manual(values = c("#009444","#ff7f00")) +
scale_y_continuous(limits = c(-0.6,0.9),breaks = seq(-0.6, 0.9, by = 0.3)) +
  theme_pubr(base_size = 14) +

  xlab("") +
  ylab("Beta coef of CytoSig score") 

library(reshape2)
cd8_IFNG_UP$gene = factor(row.names(cd8_IFNG_UP), levels = rev(row.names(cd8_IFNG_UP)))
cd8_IFNG_UP_melt = melt(cd8_IFNG_UP[,c("IFNG","IFN1","gene")])
#cd8_IFNG_UP_melt$same = rep("same",nrow(cd8_IFNG_UP_melt))
head(cd8_IFNG_UP_melt)

IFNG_plot = ggplot(cd8_IFNG_UP_melt) +
    geom_hline(lty = 2, yintercept = 0,color = "black") +
  geom_segment( aes(x=gene, xend=gene, y=0, yend=value), color="gray50") +
  geom_point( aes(x=gene, y=value, color=variable), size=4 ) +
  coord_flip()+scale_color_manual(values = c("#009444","#ff7f00")) +
scale_y_continuous(limits = c(-0.6,0.9),breaks = seq(-0.6, 0.9, by = 0.3)) +
  theme_pubr(base_size = 14) +

  xlab("") +
  ylab("Beta coef of CytoSig score") 

plot_grid(IFN1_plot, IFNG_plot, ncol = 1,align = "v")

ggsave("../Figures/Figure1/Figure1F_CD8_MixedEffects_Lollipops.pdf",width = 3.8, height = 10)
# Out:
# Using gene as id variables
#   gene    variable value
# 1 IFI6    IFNG     -0.145293570
# 2 IFIT3   IFNG      0.042402272
# 3 IFIT1   IFNG      0.019937084
# 4 IRF7    IFNG     -0.027315006
# 5 IFI44L  IFNG      0.003438403
# 6 EIF2AK2 IFNG     -0.073542436
# Using gene as id variables
#   gene   variable value
# 1 IRF1   IFNG     0.6838097
# 2 GBP2   IFNG     0.4359742
# 3 PSMB10 IFNG     0.2843101
# 4 VAMP5  IFNG     0.2578800
# 5 PSMB8  IFNG     0.2014064
# 6 TRAFD1 IFNG     0.1606369
# plot without title

# %% [markdown]
# ### Manually check over metadata, cross-referencing against original studies <a name="5"></a>

# %%
seur_full
# Out:
# An object of class Seurat
# 39619 features across 228371 samples within 1 assay
# Active assay: RNA (39619 features, 2000 variable features)
#  3 dimensional reductions calculated: pca, harmony, umap

# %%
colnames(seur_full@meta.data)
# Out:
#  [1] "orig.ident"                "nCount_RNA"
#  [3] "nFeature_RNA"              "Sample"
#  [5] "cell_id"                   "Cohort"
#  [7] "Chemistry"                 "Treated"
#  [9] "IO"                        "TKI"
# [11] "Biopsy"                    "Stage"
# [13] "SampleName"                "Patient"
# [15] "Location"                  "Histology"
# [17] "percent.mt"                "RNA_snn_res.0.5"
# [19] "seurat_clusters"           "RNA_snn_res.0.3"
# [21] "RNA_snn_res.0.2"           "rownames"
# [23] "InferCNV_Call"             "Broad_CellType"
# [25] "InferCNV_Call_Manuscript"  "original_anno"
# [27] "Idents_goodcells"          "Idents_granular"
# [29] "object"                    "BBK_Broad_Celltype"
# [31] "BBK_Final_Celltype"        "Stage_Corrected"
# [33] "Stage_Corrected_EarlyLate" "IO_Treated"
# [35] "BBK_Broad_Celltype_DE"     "sample_id"
# [37] "Minn_Benci_ISG.RS"         "Minn_Benci_IFNG.GS"
# [39] "Lineage"

# %%
Bi = subset(seur_full@meta.data, Cohort == "Bi")[,c("Patient","SampleName","Sample","Biopsy","Cohort","Stage_Corrected","Stage_Corrected_EarlyLate","Treated","IO_Treated","IO","TKI")]
head(Bi)
table(Bi$SampleName)
length(unique(Bi$Patient))
length(unique(Bi$SampleName))
# Out:
#                                  Patient SampleName Sample        Biopsy
# AAAGCAAAGTGGTCCC-1.Bi_0600855_T3 P55     P55        Bi_0600855_T3 Abdomen
# CCGGGATAGGTGATTA-1.Bi_0600855_T3 P55     P55        Bi_0600855_T3 Abdomen
# TGAAAGACAAGGGTCA-1.Bi_0600855_T3 P55     P55        Bi_0600855_T3 Abdomen
# TTTGCGCAGCTGAACG-1.Bi_0600855_T3 P55     P55        Bi_0600855_T3 Abdomen
# CTACGTCCACATCTTT-1.Bi_0600855_T3 P55     P55        Bi_0600855_T3 Abdomen
# AGTGGGACAAACAACA-1.Bi_0600855_T3 P55     P55        Bi_0600855_T3 Abdomen
#                                  Cohort Stage_Corrected
# AAAGCAAAGTGGTCCC-1.Bi_0600855_T3 Bi     IV
# CCGGGATAGGTGATTA-1.Bi_0600855_T3 Bi     IV
# TGAAAGACAAGGGTCA-1.Bi_0600855_T3 Bi     IV
# TTTGCGCAGCTGAACG-1.Bi_0600855_T3 Bi     IV
# CTACGTCCACATCTTT-1.Bi_0600855_T3 Bi     IV
# AGTGGGACAAACAACA-1.Bi_0600855_T3 Bi     IV
#                                  Stage_Corrected_EarlyLate Treated IO_Treated
# AAAGCAAAGTGGTCCC-1.Bi_0600855_T3 Late                      Yes     IO Exposed
# CCGGGATAGGTGATTA-1.Bi_0600855_T3 Late                      Yes     IO Exposed
# TGAAAGACAAGGGTCA-1.Bi_0600855_T3 Late                      Yes     IO Exposed
# TTTGCGCAGCTGAACG-1.Bi_0600855_T3 Late                      Yes     IO Exposed
# CTACGTCCACATCTTT-1.Bi_0600855_T3 Late                      Yes     IO Exposed
# AGTGGGACAAACAACA-1.Bi_0600855_T3 Late                      Yes     IO Exposed
#                                  IO TKI
# AAAGCAAAGTGGTCCC-1.Bi_0600855_T3 PR Yes
# CCGGGATAGGTGATTA-1.Bi_0600855_T3 PR Yes
# TGAAAGACAAGGGTCA-1.Bi_0600855_T3 PR Yes
# TTTGCGCAGCTGAACG-1.Bi_0600855_T3 PR Yes
# CTACGTCCACATCTTT-1.Bi_0600855_T3 PR Yes
# AGTGGGACAAACAACA-1.Bi_0600855_T3 PR Yes
#  P55  P76  P90 P906 P912 P913 P915 P916
# 3924 5705 6455 1605  213 2722 5726  226
# [1] 8
# [1] 8

# %%
Bi_SampleName = unique(Bi$SampleName)
subset(Bi, SampleName == Bi_SampleName[[1]])[1,]

#Passed
# Out:
#                                  Patient SampleName Sample        Biopsy
# AAAGCAAAGTGGTCCC-1.Bi_0600855_T3 P55     P55        Bi_0600855_T3 Abdomen
#                                  Cohort Stage_Corrected
# AAAGCAAAGTGGTCCC-1.Bi_0600855_T3 Bi     IV
#                                  Stage_Corrected_EarlyLate Treated IO_Treated
# AAAGCAAAGTGGTCCC-1.Bi_0600855_T3 Late                      Yes     IO Exposed
#                                  IO TKI
# AAAGCAAAGTGGTCCC-1.Bi_0600855_T3 PR Yes

# %%
Bi_SampleName = unique(Bi$SampleName)
subset(Bi, SampleName == Bi_SampleName[[2]])[1,]

#Passed
# Out:
#                                  Patient SampleName Sample        Biopsy
# CCGGTAGAGATGTCGG-1.Bi_0600906_T1 P906    P906       Bi_0600906_T1 Lymph_node
#                                  Cohort Stage_Corrected
# CCGGTAGAGATGTCGG-1.Bi_0600906_T1 Bi     IV
#                                  Stage_Corrected_EarlyLate Treated IO_Treated
# CCGGTAGAGATGTCGG-1.Bi_0600906_T1 Late                      Yes     IO Exposed
#                                  IO TKI
# CCGGTAGAGATGTCGG-1.Bi_0600906_T1 PD Yes

# %%
Bi_SampleName = unique(Bi$SampleName)
subset(Bi, SampleName == Bi_SampleName[[3]])[1,]

#Passed
# Out:
#                                  Patient SampleName Sample        Biopsy Cohort
# GACGGCTAGTCCGTAT-1.Bi_0600913_T1 P913    P913       Bi_0600913_T1 Lung   Bi
#                                  Stage_Corrected Stage_Corrected_EarlyLate
# GACGGCTAGTCCGTAT-1.Bi_0600913_T1 IV              Late
#                                  Treated IO_Treated IO TKI
# GACGGCTAGTCCGTAT-1.Bi_0600913_T1 Yes     IO Exposed SD Yes

# %%
Bi_SampleName = unique(Bi$SampleName)
subset(Bi, SampleName == Bi_SampleName[[4]])[1,]

#Passed
# Out:
#                                            Patient SampleName
# AGCTCCTCAAAGGCGT-1.Bi_0600915_T1_TrueTumor P915    P915
#                                            Sample                  Biopsy
# AGCTCCTCAAAGGCGT-1.Bi_0600915_T1_TrueTumor Bi_0600915_T1_TrueTumor Kidney
#                                            Cohort Stage_Corrected
# AGCTCCTCAAAGGCGT-1.Bi_0600915_T1_TrueTumor Bi     III
#                                            Stage_Corrected_EarlyLate Treated
# AGCTCCTCAAAGGCGT-1.Bi_0600915_T1_TrueTumor Late                      Yes
#                                            IO_Treated IO TKI
# AGCTCCTCAAAGGCGT-1.Bi_0600915_T1_TrueTumor IO Exposed PR No

# %%
Bi_SampleName = unique(Bi$SampleName)
subset(Bi, SampleName == Bi_SampleName[[5]])[1,]

#Passed
# Out:
#                                  Patient SampleName Sample        Biopsy
# TATTACCTCAACTCTT-1.Bi_0600916_T1 P916    P916       Bi_0600916_T1 Lymph_node
#                                  Cohort Stage_Corrected
# TATTACCTCAACTCTT-1.Bi_0600916_T1 Bi     IV
#                                  Stage_Corrected_EarlyLate Treated IO_Treated
# TATTACCTCAACTCTT-1.Bi_0600916_T1 Late                      No      IO Naive
#                                  IO TKI
# TATTACCTCAACTCTT-1.Bi_0600916_T1 No No

# %%
Bi_SampleName = unique(Bi$SampleName)
subset(Bi, SampleName == Bi_SampleName[[6]])[1,]

#Passed
# Out:
#                                       Patient SampleName Sample
# AGGGATGAGACCGGAT-1.Bi_DFCI_0600876_T1 P76     P76        Bi_DFCI_0600876_T1
#                                       Biopsy Cohort Stage_Corrected
# AGGGATGAGACCGGAT-1.Bi_DFCI_0600876_T1 Kidney Bi     IV
#                                       Stage_Corrected_EarlyLate Treated
# AGGGATGAGACCGGAT-1.Bi_DFCI_0600876_T1 Late                      No
#                                       IO_Treated IO TKI
# AGGGATGAGACCGGAT-1.Bi_DFCI_0600876_T1 IO Naive   No No

# %%
Bi_SampleName = unique(Bi$SampleName)
subset(Bi, SampleName == Bi_SampleName[[7]])[1,]

#Passed
# Out:
#                                       Patient SampleName Sample
# TCACGAATCTCCCTGA-1.Bi_DFCI_0600890_T1 P90     P90        Bi_DFCI_0600890_T1
#                                       Biopsy Cohort Stage_Corrected
# TCACGAATCTCCCTGA-1.Bi_DFCI_0600890_T1 Kidney Bi     I
#                                       Stage_Corrected_EarlyLate Treated
# TCACGAATCTCCCTGA-1.Bi_DFCI_0600890_T1 Early                     No
#                                       IO_Treated IO TKI
# TCACGAATCTCCCTGA-1.Bi_DFCI_0600890_T1 IO Naive   No No

# %%
Bi_SampleName = unique(Bi$SampleName)
subset(Bi, SampleName == Bi_SampleName[[8]])[1,]

#Passed
# Out:
#                                  Patient SampleName Sample        Biopsy
# TCGCGAGAGCGTTGCC-1.Bi_0600912_T1 P912    P912       Bi_0600912_T1 Lymph_node
#                                  Cohort Stage_Corrected
# TCGCGAGAGCGTTGCC-1.Bi_0600912_T1 Bi     IV
#                                  Stage_Corrected_EarlyLate Treated IO_Treated
# TCGCGAGAGCGTTGCC-1.Bi_0600912_T1 Late                      Yes     IO Exposed
#                                  IO TKI
# TCGCGAGAGCGTTGCC-1.Bi_0600912_T1 NE Yes

# %% [markdown]
# ### Bi & He cohort - all samples passed manual metadata check

# %%
Braun = subset(seur_full@meta.data, Cohort == "Braun")[,c("Patient","SampleName","Sample","Biopsy","Cohort","Stage_Corrected","Stage_Corrected_EarlyLate","Treated","IO_Treated","IO","TKI")]
head(Braun)
table(Braun$SampleName)
length(unique(Braun$Patient))
length(unique(Braun$SampleName))
# Out:
#                             Patient SampleName Sample   Biopsy Cohort
# GTTCTCGAGAGGTAGA-1.5pool1_2 S1      S1_T       5pool1_2 Kidney Braun
# CTAGAGTCATCAGTCA-1.5pool1_2 S1      S1_T       5pool1_2 Kidney Braun
# CGGCTAGAGGTAGCCA-1.5pool1_2 S1      S1_T       5pool1_2 Kidney Braun
# CTGCTGTAGTGTTTGC-1.5pool1_2 S1      S1_T       5pool1_2 Kidney Braun
# CCATGTCCATCGATGT-1.5pool1_2 S1      S1_T       5pool1_2 Kidney Braun
# TCTGAGAAGCGTAATA-1.5pool1_2 S1      S1_T       5pool1_2 Kidney Braun
#                             Stage_Corrected Stage_Corrected_EarlyLate Treated
# GTTCTCGAGAGGTAGA-1.5pool1_2 I               Early                     No
# CTAGAGTCATCAGTCA-1.5pool1_2 I               Early                     No
# CGGCTAGAGGTAGCCA-1.5pool1_2 I               Early                     No
# CTGCTGTAGTGTTTGC-1.5pool1_2 I               Early                     No
# CCATGTCCATCGATGT-1.5pool1_2 I               Early                     No
# TCTGAGAAGCGTAATA-1.5pool1_2 I               Early                     No
#                             IO_Treated IO TKI
# GTTCTCGAGAGGTAGA-1.5pool1_2 IO Naive   No No
# CTAGAGTCATCAGTCA-1.5pool1_2 IO Naive   No No
# CGGCTAGAGGTAGCCA-1.5pool1_2 IO Naive   No No
# CTGCTGTAGTGTTTGC-1.5pool1_2 IO Naive   No No
# CCATGTCCATCGATGT-1.5pool1_2 IO Naive   No No
# TCTGAGAAGCGTAATA-1.5pool1_2 IO Naive   No No
# S10_T S11_M S11_T S12_T S12_V S14_T S15_T S16_T  S1_T  S2_T  S3_T  S5_T  S6_T
#   101   252  3314  6083  9561   771 16599  8936 12007 12996  1934  9963  9540
#  S7_T  S8_T
#  5779  6858
# [1] 13
# [1] 15

# %%
Braun_SampleName = unique(Braun$SampleName)
subset(Braun, SampleName == Braun_SampleName[[1]])[1,]

#Passed
# Out:
#                             Patient SampleName Sample   Biopsy Cohort
# GTTCTCGAGAGGTAGA-1.5pool1_2 S1      S1_T       5pool1_2 Kidney Braun
#                             Stage_Corrected Stage_Corrected_EarlyLate Treated
# GTTCTCGAGAGGTAGA-1.5pool1_2 I               Early                     No
#                             IO_Treated IO TKI
# GTTCTCGAGAGGTAGA-1.5pool1_2 IO Naive   No No

# %%
Braun_SampleName = unique(Braun$SampleName)
subset(Braun, SampleName == Braun_SampleName[[2]])[1,]

#Passed
# Out:
#                              Patient SampleName Sample    Biopsy  Cohort
# TACCTATGTCTAGAGG-1.Pool70-10 S5      S5_T       Pool70-10 Adrenal Braun
#                              Stage_Corrected Stage_Corrected_EarlyLate Treated
# TACCTATGTCTAGAGG-1.Pool70-10 IV              Late                      No
#                              IO_Treated IO TKI
# TACCTATGTCTAGAGG-1.Pool70-10 IO Naive   No No

# %%
Braun_SampleName = unique(Braun$SampleName)
subset(Braun, SampleName == Braun_SampleName[[3]])[1,]

#Passed
# Out:
#                             Patient SampleName Sample   Biopsy Cohort
# GTGCAGCTCACCTTAT-1.Pool70-6 S2      S2_T       Pool70-6 Kidney Braun
#                             Stage_Corrected Stage_Corrected_EarlyLate Treated
# GTGCAGCTCACCTTAT-1.Pool70-6 I               Early                     No
#                             IO_Treated IO TKI
# GTGCAGCTCACCTTAT-1.Pool70-6 IO Naive   No No

# %%
Braun_SampleName = unique(Braun$SampleName)
subset(Braun, SampleName == Braun_SampleName[[4]])[1,]

#Passed
# Out:
#                             Patient SampleName Sample   Biopsy Cohort
# TCGGTAAAGTAGTGCG-1.Pool71-5 S11     S11_T      Pool71-5 Kidney Braun
#                             Stage_Corrected Stage_Corrected_EarlyLate Treated
# TCGGTAAAGTAGTGCG-1.Pool71-5 IV              Late                      No
#                             IO_Treated IO TKI
# TCGGTAAAGTAGTGCG-1.Pool71-5 IO Naive   No No

# %%
Braun_SampleName = unique(Braun$SampleName)
subset(Braun, SampleName == Braun_SampleName[[5]])[1,]

#Passed
# Out:
#                             Patient SampleName Sample   Biopsy  Cohort
# AGCGGTCGTTGGTTTG-1.Pool71-6 S11     S11_M      Pool71-6 Abdomen Braun
#                             Stage_Corrected Stage_Corrected_EarlyLate Treated
# AGCGGTCGTTGGTTTG-1.Pool71-6 IV              Late                      No
#                             IO_Treated IO TKI
# AGCGGTCGTTGGTTTG-1.Pool71-6 IO Naive   No No

# %%
Braun_SampleName = unique(Braun$SampleName)
subset(Braun, SampleName == Braun_SampleName[[6]])[1,]

#Passed
# Out:
#                             Patient SampleName Sample   Biopsy Cohort
# AACTCTTGTGGACGAT-1.Pool72-2 S8      S8_T       Pool72-2 Kidney Braun
#                             Stage_Corrected Stage_Corrected_EarlyLate Treated
# AACTCTTGTGGACGAT-1.Pool72-2 II              Early                     No
#                             IO_Treated IO TKI
# AACTCTTGTGGACGAT-1.Pool72-2 IO Naive   No No

# %%
Braun_SampleName = unique(Braun$SampleName)
subset(Braun, SampleName == Braun_SampleName[[7]])[1,]

#Passed
# Out:
#                             Patient SampleName Sample   Biopsy Cohort
# CGTGAGCTCAACGAAA-1.Pool72-4 S14     S14_T      Pool72-4 Kidney Braun
#                             Stage_Corrected Stage_Corrected_EarlyLate Treated
# CGTGAGCTCAACGAAA-1.Pool72-4 III             Late                      No
#                             IO_Treated IO TKI
# CGTGAGCTCAACGAAA-1.Pool72-4 IO Naive   No No

# %%
Braun_SampleName = unique(Braun$SampleName)
subset(Braun, SampleName == Braun_SampleName[[8]])[1,]

#Passed
# Out:
#                             Patient SampleName Sample   Biopsy Cohort
# GCATACATCATGCTCC-1.Pool73-3 S7      S7_T       Pool73-3 Kidney Braun
#                             Stage_Corrected Stage_Corrected_EarlyLate Treated
# GCATACATCATGCTCC-1.Pool73-3 III             Late                      No
#                             IO_Treated IO TKI
# GCATACATCATGCTCC-1.Pool73-3 IO Naive   No No

# %%
Braun_SampleName = unique(Braun$SampleName)
subset(Braun, SampleName == Braun_SampleName[[9]])[1,]

#Passed
# Out:
#                             Patient SampleName Sample   Biopsy Cohort
# TGCGTGGGTCTAAACC-1.Pool73-4 S15     S15_T      Pool73-4 Kidney Braun
#                             Stage_Corrected Stage_Corrected_EarlyLate Treated
# TGCGTGGGTCTAAACC-1.Pool73-4 IV              Late                      No
#                             IO_Treated IO TKI
# TGCGTGGGTCTAAACC-1.Pool73-4 IO Naive   No No

# %%
Braun_SampleName = unique(Braun$SampleName)
subset(Braun, SampleName == Braun_SampleName[[10]])[1,]

#Passed
# Out:
#                             Patient SampleName Sample   Biopsy Cohort
# AGGTCATTCCGATATG-1.Pool73-5 S16     S16_T      Pool73-5 Kidney Braun
#                             Stage_Corrected Stage_Corrected_EarlyLate Treated
# AGGTCATTCCGATATG-1.Pool73-5 IV              Late                      No
#                             IO_Treated IO TKI
# AGGTCATTCCGATATG-1.Pool73-5 IO Naive   No No

# %%
Braun_SampleName = unique(Braun$SampleName)
subset(Braun, SampleName == Braun_SampleName[[11]])[1,]

#Passed
# Out:
#                             Patient SampleName Sample
# TTTGTCATCACTATTC-1.Pool73-6 S12     S12_V      Pool73-6
#                             Biopsy                    Cohort Stage_Corrected
# TTTGTCATCACTATTC-1.Pool73-6 Renal_vein_tumor_thrombus Braun  III
#                             Stage_Corrected_EarlyLate Treated IO_Treated IO TKI
# TTTGTCATCACTATTC-1.Pool73-6 Late                      No      IO Naive   No No

# %%
Braun_SampleName = unique(Braun$SampleName)
subset(Braun, SampleName == Braun_SampleName[[12]])[1,]

#Passed
# Out:
#                             Patient SampleName Sample   Biopsy Cohort
# CTCATTACATCCGCGA-1.Pool70-8 S3      S3_T       Pool70-8 Kidney Braun
#                             Stage_Corrected Stage_Corrected_EarlyLate Treated
# CTCATTACATCCGCGA-1.Pool70-8 III             Late                      No
#                             IO_Treated IO TKI
# CTCATTACATCCGCGA-1.Pool70-8 IO Naive   No No

# %%
Braun_SampleName = unique(Braun$SampleName)
subset(Braun, SampleName == Braun_SampleName[[13]])[1,]

#Passed
# Out:
#                             Patient SampleName Sample   Biopsy Cohort
# CTAGCCTTCGTAGATC-1.Pool71-3 S6      S6_T       Pool71-3 Kidney Braun
#                             Stage_Corrected Stage_Corrected_EarlyLate Treated
# CTAGCCTTCGTAGATC-1.Pool71-3 I               Early                     No
#                             IO_Treated IO TKI
# CTAGCCTTCGTAGATC-1.Pool71-3 IO Naive   No No

# %%
Braun_SampleName = unique(Braun$SampleName)
subset(Braun, SampleName == Braun_SampleName[[14]])[1,]

#Passed
# Out:
#                             Patient SampleName Sample   Biopsy Cohort
# GGACATTGTGTTTGGT-1.Pool71-8 S12     S12_T      Pool71-8 Kidney Braun
#                             Stage_Corrected Stage_Corrected_EarlyLate Treated
# GGACATTGTGTTTGGT-1.Pool71-8 III             Late                      No
#                             IO_Treated IO TKI
# GGACATTGTGTTTGGT-1.Pool71-8 IO Naive   No No

# %%
Braun_SampleName = unique(Braun$SampleName)
subset(Braun, SampleName == Braun_SampleName[[15]])[1,]

#Passed
# Out:
#                              Patient SampleName Sample    Biopsy Cohort
# CTCAGAACAAAGAATC-1.Pool72-10 S10     S10_T      Pool72-10 Kidney Braun
#                              Stage_Corrected Stage_Corrected_EarlyLate Treated
# CTCAGAACAAAGAATC-1.Pool72-10 IV              Late                      No
#                              IO_Treated IO TKI
# CTCAGAACAAAGAATC-1.Pool72-10 IO Naive   No No

# %% [markdown]
# ### Braun cohort - all samples passed manual metadata check

# %%
Krishna = subset(seur_full@meta.data, Cohort == "Krishna")[,c("Patient","SampleName","Sample","Biopsy","Cohort","Stage_Corrected","Stage_Corrected_EarlyLate","Treated","IO_Treated","IO","TKI")]
head(Krishna)
table(Krishna$SampleName)
length(unique(Krishna$Patient))
length(unique(Krishna$SampleName))
# Out:
#                                         Patient       SampleName
# GGTGCGTAGTTTGCGT-1.IpiNivo_Mixed_Center IpiNivo_Mixed IpiNivo_Mixed_Center
# CTAGTGAAGTGAAGTT-1.IpiNivo_Mixed_Center IpiNivo_Mixed IpiNivo_Mixed_Center
# CGTAGGCAGTAGCCGA-1.IpiNivo_Mixed_Center IpiNivo_Mixed IpiNivo_Mixed_Center
# TTGAACGGTCTGGAGA-1.IpiNivo_Mixed_Center IpiNivo_Mixed IpiNivo_Mixed_Center
# CGGTTAAAGGCTAGCA-1.IpiNivo_Mixed_Center IpiNivo_Mixed IpiNivo_Mixed_Center
# AGGGAGTTCCTGCCAT-1.IpiNivo_Mixed_Center IpiNivo_Mixed IpiNivo_Mixed_Center
#                                         Sample               Biopsy Cohort
# GGTGCGTAGTTTGCGT-1.IpiNivo_Mixed_Center IpiNivo_Mixed_Center Kidney Krishna
# CTAGTGAAGTGAAGTT-1.IpiNivo_Mixed_Center IpiNivo_Mixed_Center Kidney Krishna
# CGTAGGCAGTAGCCGA-1.IpiNivo_Mixed_Center IpiNivo_Mixed_Center Kidney Krishna
# TTGAACGGTCTGGAGA-1.IpiNivo_Mixed_Center IpiNivo_Mixed_Center Kidney Krishna
# CGGTTAAAGGCTAGCA-1.IpiNivo_Mixed_Center IpiNivo_Mixed_Center Kidney Krishna
# AGGGAGTTCCTGCCAT-1.IpiNivo_Mixed_Center IpiNivo_Mixed_Center Kidney Krishna
#                                         Stage_Corrected
# GGTGCGTAGTTTGCGT-1.IpiNivo_Mixed_Center IV
# CTAGTGAAGTGAAGTT-1.IpiNivo_Mixed_Center IV
# CGTAGGCAGTAGCCGA-1.IpiNivo_Mixed_Center IV
# TTGAACGGTCTGGAGA-1.IpiNivo_Mixed_Center IV
# CGGTTAAAGGCTAGCA-1.IpiNivo_Mixed_Center IV
# AGGGAGTTCCTGCCAT-1.IpiNivo_Mixed_Center IV
#                                         Stage_Corrected_EarlyLate Treated
# GGTGCGTAGTTTGCGT-1.IpiNivo_Mixed_Center Late                      Yes
# CTAGTGAAGTGAAGTT-1.IpiNivo_Mixed_Center Late                      Yes
# CGTAGGCAGTAGCCGA-1.IpiNivo_Mixed_Center Late                      Yes
# TTGAACGGTCTGGAGA-1.IpiNivo_Mixed_Center Late                      Yes
# CGGTTAAAGGCTAGCA-1.IpiNivo_Mixed_Center Late                      Yes
# AGGGAGTTCCTGCCAT-1.IpiNivo_Mixed_Center Late                      Yes
#                                         IO_Treated IO  TKI
# GGTGCGTAGTTTGCGT-1.IpiNivo_Mixed_Center IO Exposed Yes No
# CTAGTGAAGTGAAGTT-1.IpiNivo_Mixed_Center IO Exposed Yes No
# CGTAGGCAGTAGCCGA-1.IpiNivo_Mixed_Center IO Exposed Yes No
# TTGAACGGTCTGGAGA-1.IpiNivo_Mixed_Center IO Exposed Yes No
# CGGTTAAAGGCTAGCA-1.IpiNivo_Mixed_Center IO Exposed Yes No
# AGGGAGTTCCTGCCAT-1.IpiNivo_Mixed_Center IO Exposed Yes No
#  IpiNivo_CompleteResponse_Center IpiNivo_CompleteResponse_Lateral
#                              748                             4653
#  IpiNivo_CompleteResponse_Medial             IpiNivo_Mixed_Center
#                              956                             7512
#                IpiNivo_Mixed_Far               IpiNivo_Mixed_Near
#                             7961                             7379
#         IpiNivo_Resistant_Center            IpiNivo_Resistant_Far
#                             6419                             7439
#      IpiNivo_Resistant_LymphNode           IpiNivo_Resistant_Near
#                             3417                             5481
#         NivoExposed_LowerLateral          NivoExposed_LowerMedial
#                             6023                              818
#         NivoExposed_SupraLateral                       UT1_Center
#                            11994                             5380
#                        UT1_Lower                        UT1_Upper
#                             6369                             5613
#                       UT2_Center                          UT2_Far
#                             4672                             3466
#                         UT2_Near
#                              801
# [1] 6
# [1] 19

# %%
Krishna_SampleName = unique(Krishna$SampleName)
subset(Krishna, SampleName == Krishna_SampleName[[1]])[1,]

#Passed
# Out:
#                                         Patient       SampleName
# GGTGCGTAGTTTGCGT-1.IpiNivo_Mixed_Center IpiNivo_Mixed IpiNivo_Mixed_Center
#                                         Sample               Biopsy Cohort
# GGTGCGTAGTTTGCGT-1.IpiNivo_Mixed_Center IpiNivo_Mixed_Center Kidney Krishna
#                                         Stage_Corrected
# GGTGCGTAGTTTGCGT-1.IpiNivo_Mixed_Center IV
#                                         Stage_Corrected_EarlyLate Treated
# GGTGCGTAGTTTGCGT-1.IpiNivo_Mixed_Center Late                      Yes
#                                         IO_Treated IO  TKI
# GGTGCGTAGTTTGCGT-1.IpiNivo_Mixed_Center IO Exposed Yes No

# %%
Krishna_SampleName = unique(Krishna$SampleName)
subset(Krishna, SampleName == Krishna_SampleName[[2]])[1,]

#Passed
# Out:
#                                      Patient       SampleName
# TCAGGTAGTTCTGGTA-1.IpiNivo_Mixed_Far IpiNivo_Mixed IpiNivo_Mixed_Far
#                                      Sample            Biopsy Cohort
# TCAGGTAGTTCTGGTA-1.IpiNivo_Mixed_Far IpiNivo_Mixed_Far Kidney Krishna
#                                      Stage_Corrected Stage_Corrected_EarlyLate
# TCAGGTAGTTCTGGTA-1.IpiNivo_Mixed_Far IV              Late
#                                      Treated IO_Treated IO  TKI
# TCAGGTAGTTCTGGTA-1.IpiNivo_Mixed_Far Yes     IO Exposed Yes No

# %%
Krishna_SampleName = unique(Krishna$SampleName)
subset(Krishna, SampleName == Krishna_SampleName[[3]])[1,]

#Passed
# Out:
#                                       Patient       SampleName
# ACTTGTTCACAGTCGC-1.IpiNivo_Mixed_Near IpiNivo_Mixed IpiNivo_Mixed_Near
#                                       Sample             Biopsy Cohort
# ACTTGTTCACAGTCGC-1.IpiNivo_Mixed_Near IpiNivo_Mixed_Near Kidney Krishna
#                                       Stage_Corrected Stage_Corrected_EarlyLate
# ACTTGTTCACAGTCGC-1.IpiNivo_Mixed_Near IV              Late
#                                       Treated IO_Treated IO  TKI
# ACTTGTTCACAGTCGC-1.IpiNivo_Mixed_Near Yes     IO Exposed Yes No

# %%
Krishna_SampleName = unique(Krishna$SampleName)
subset(Krishna, SampleName == Krishna_SampleName[[4]])[1,]

#Passed
# Out:
#                                             Patient
# CACACTCAGCTAGTGG-1.IpiNivo_Resistant_Center IpiNivo_Resistant
#                                             SampleName
# CACACTCAGCTAGTGG-1.IpiNivo_Resistant_Center IpiNivo_Resistant_Center
#                                             Sample                   Biopsy
# CACACTCAGCTAGTGG-1.IpiNivo_Resistant_Center IpiNivo_Resistant_Center Kidney
#                                             Cohort  Stage_Corrected
# CACACTCAGCTAGTGG-1.IpiNivo_Resistant_Center Krishna IV
#                                             Stage_Corrected_EarlyLate Treated
# CACACTCAGCTAGTGG-1.IpiNivo_Resistant_Center Late                      Yes
#                                             IO_Treated IO  TKI
# CACACTCAGCTAGTGG-1.IpiNivo_Resistant_Center IO Exposed Yes No

# %%
Krishna_SampleName = unique(Krishna$SampleName)
subset(Krishna, SampleName == Krishna_SampleName[[5]])[1,]

#Passed
# Out:
#                                          Patient
# CCTACACCACTTAACG-1.IpiNivo_Resistant_Far IpiNivo_Resistant
#                                          SampleName
# CCTACACCACTTAACG-1.IpiNivo_Resistant_Far IpiNivo_Resistant_Far
#                                          Sample                Biopsy Cohort
# CCTACACCACTTAACG-1.IpiNivo_Resistant_Far IpiNivo_Resistant_Far Kidney Krishna
#                                          Stage_Corrected
# CCTACACCACTTAACG-1.IpiNivo_Resistant_Far IV
#                                          Stage_Corrected_EarlyLate Treated
# CCTACACCACTTAACG-1.IpiNivo_Resistant_Far Late                      Yes
#                                          IO_Treated IO  TKI
# CCTACACCACTTAACG-1.IpiNivo_Resistant_Far IO Exposed Yes No

# %%
Krishna_SampleName = unique(Krishna$SampleName)
subset(Krishna, SampleName == Krishna_SampleName[[6]])[1,]

#Passed
# Out:
#                                                Patient
# CGCTTCACATGGTTGT-1.IpiNivo_Resistant_LymphNode IpiNivo_Resistant
#                                                SampleName
# CGCTTCACATGGTTGT-1.IpiNivo_Resistant_LymphNode IpiNivo_Resistant_LymphNode
#                                                Sample
# CGCTTCACATGGTTGT-1.IpiNivo_Resistant_LymphNode IpiNivo_Resistant_LymphNode
#                                                Biopsy     Cohort
# CGCTTCACATGGTTGT-1.IpiNivo_Resistant_LymphNode Lymph_node Krishna
#                                                Stage_Corrected
# CGCTTCACATGGTTGT-1.IpiNivo_Resistant_LymphNode IV
#                                                Stage_Corrected_EarlyLate
# CGCTTCACATGGTTGT-1.IpiNivo_Resistant_LymphNode Late
#                                                Treated IO_Treated IO  TKI
# CGCTTCACATGGTTGT-1.IpiNivo_Resistant_LymphNode Yes     IO Exposed Yes No

# %%
Krishna_SampleName = unique(Krishna$SampleName)
subset(Krishna, SampleName == Krishna_SampleName[[7]])[1,]

#Passed
# Out:
#                                           Patient
# CTGCTGTAGGATGCGT-1.IpiNivo_Resistant_Near IpiNivo_Resistant
#                                           SampleName
# CTGCTGTAGGATGCGT-1.IpiNivo_Resistant_Near IpiNivo_Resistant_Near
#                                           Sample                 Biopsy Cohort
# CTGCTGTAGGATGCGT-1.IpiNivo_Resistant_Near IpiNivo_Resistant_Near Kidney Krishna
#                                           Stage_Corrected
# CTGCTGTAGGATGCGT-1.IpiNivo_Resistant_Near IV
#                                           Stage_Corrected_EarlyLate Treated
# CTGCTGTAGGATGCGT-1.IpiNivo_Resistant_Near Late                      Yes
#                                           IO_Treated IO  TKI
# CTGCTGTAGGATGCGT-1.IpiNivo_Resistant_Near IO Exposed Yes No

# %%
Krishna_SampleName = unique(Krishna$SampleName)
subset(Krishna, SampleName == Krishna_SampleName[[8]])[1,]

#Passed
# Out:
#                                             Patient
# TCGCGAGAGGAATGGA-1.NivoExposed_LowerLateral NivoExposed
#                                             SampleName
# TCGCGAGAGGAATGGA-1.NivoExposed_LowerLateral NivoExposed_LowerLateral
#                                             Sample                   Biopsy
# TCGCGAGAGGAATGGA-1.NivoExposed_LowerLateral NivoExposed_LowerLateral Kidney
#                                             Cohort  Stage_Corrected
# TCGCGAGAGGAATGGA-1.NivoExposed_LowerLateral Krishna III
#                                             Stage_Corrected_EarlyLate Treated
# TCGCGAGAGGAATGGA-1.NivoExposed_LowerLateral Late                      Yes
#                                             IO_Treated IO  TKI
# TCGCGAGAGGAATGGA-1.NivoExposed_LowerLateral IO Exposed Yes No

# %%
Krishna_SampleName = unique(Krishna$SampleName)
subset(Krishna, SampleName == Krishna_SampleName[[9]])[1,]

#Passed
# Out:
#                                            Patient     SampleName
# ATCATGGCATGGTCAT-1.NivoExposed_LowerMedial NivoExposed NivoExposed_LowerMedial
#                                            Sample                  Biopsy
# ATCATGGCATGGTCAT-1.NivoExposed_LowerMedial NivoExposed_LowerMedial Kidney
#                                            Cohort  Stage_Corrected
# ATCATGGCATGGTCAT-1.NivoExposed_LowerMedial Krishna III
#                                            Stage_Corrected_EarlyLate Treated
# ATCATGGCATGGTCAT-1.NivoExposed_LowerMedial Late                      Yes
#                                            IO_Treated IO  TKI
# ATCATGGCATGGTCAT-1.NivoExposed_LowerMedial IO Exposed Yes No

# %%
Krishna_SampleName = unique(Krishna$SampleName)
subset(Krishna, SampleName == Krishna_SampleName[[10]])[1,]

#Passed
# Out:
#                                             Patient
# TGCCCATTCTACTCAT-1.NivoExposed_SupraLateral NivoExposed
#                                             SampleName
# TGCCCATTCTACTCAT-1.NivoExposed_SupraLateral NivoExposed_SupraLateral
#                                             Sample                   Biopsy
# TGCCCATTCTACTCAT-1.NivoExposed_SupraLateral NivoExposed_SupraLateral Kidney
#                                             Cohort  Stage_Corrected
# TGCCCATTCTACTCAT-1.NivoExposed_SupraLateral Krishna III
#                                             Stage_Corrected_EarlyLate Treated
# TGCCCATTCTACTCAT-1.NivoExposed_SupraLateral Late                      Yes
#                                             IO_Treated IO  TKI
# TGCCCATTCTACTCAT-1.NivoExposed_SupraLateral IO Exposed Yes No

# %%
Krishna_SampleName = unique(Krishna$SampleName)
subset(Krishna, SampleName == Krishna_SampleName[[11]])[1,]

#Passed
# Out:
#                               Patient SampleName Sample     Biopsy Cohort
# ATCGAGTTCATTTGGG-1.UT1_Center UT1     UT1_Center UT1_Center Kidney Krishna
#                               Stage_Corrected Stage_Corrected_EarlyLate Treated
# ATCGAGTTCATTTGGG-1.UT1_Center III             Late                      No
#                               IO_Treated IO TKI
# ATCGAGTTCATTTGGG-1.UT1_Center IO Naive   No No

# %%
Krishna_SampleName = unique(Krishna$SampleName)
subset(Krishna, SampleName == Krishna_SampleName[[12]])[1,]

#Passed
# Out:
#                              Patient SampleName Sample    Biopsy Cohort
# ACTGAACTCTTGTTTG-1.UT1_Upper UT1     UT1_Upper  UT1_Upper Kidney Krishna
#                              Stage_Corrected Stage_Corrected_EarlyLate Treated
# ACTGAACTCTTGTTTG-1.UT1_Upper III             Late                      No
#                              IO_Treated IO TKI
# ACTGAACTCTTGTTTG-1.UT1_Upper IO Naive   No No

# %%
Krishna_SampleName = unique(Krishna$SampleName)
subset(Krishna, SampleName == Krishna_SampleName[[13]])[1,]

#Passed
# Out:
#                               Patient SampleName Sample     Biopsy Cohort
# CTGCGGACAGACTCGC-1.UT2_Center UT2     UT2_Center UT2_Center Kidney Krishna
#                               Stage_Corrected Stage_Corrected_EarlyLate Treated
# CTGCGGACAGACTCGC-1.UT2_Center IV              Late                      No
#                               IO_Treated IO TKI
# CTGCGGACAGACTCGC-1.UT2_Center IO Naive   No No

# %%
Krishna_SampleName = unique(Krishna$SampleName)
subset(Krishna, SampleName == Krishna_SampleName[[14]])[1,]

#Passed
# Out:
#                            Patient SampleName Sample  Biopsy Cohort
# TTCTCCTTCCTAAGTG-1.UT2_Far UT2     UT2_Far    UT2_Far Kidney Krishna
#                            Stage_Corrected Stage_Corrected_EarlyLate Treated
# TTCTCCTTCCTAAGTG-1.UT2_Far IV              Late                      No
#                            IO_Treated IO TKI
# TTCTCCTTCCTAAGTG-1.UT2_Far IO Naive   No No

# %%
Krishna_SampleName = unique(Krishna$SampleName)
subset(Krishna, SampleName == Krishna_SampleName[[15]])[1,]

#Passed
# Out:
#                             Patient SampleName Sample   Biopsy Cohort
# GCATGATAGGCTCAGA-1.UT2_Near UT2     UT2_Near   UT2_Near Kidney Krishna
#                             Stage_Corrected Stage_Corrected_EarlyLate Treated
# GCATGATAGGCTCAGA-1.UT2_Near IV              Late                      No
#                             IO_Treated IO TKI
# GCATGATAGGCTCAGA-1.UT2_Near IO Naive   No No

# %%
Krishna_SampleName = unique(Krishna$SampleName)
subset(Krishna, SampleName == Krishna_SampleName[[16]])[1,]

#Passed
# Out:
#                                                    Patient
# GCACTCTTCTCTGTCG-1.IpiNivo_CompleteResponse_Center IpiNivo_CompleteResponse
#                                                    SampleName
# GCACTCTTCTCTGTCG-1.IpiNivo_CompleteResponse_Center IpiNivo_CompleteResponse_Center
#                                                    Sample
# GCACTCTTCTCTGTCG-1.IpiNivo_CompleteResponse_Center IpiNivo_CompleteResponse_Center
#                                                    Biopsy Cohort
# GCACTCTTCTCTGTCG-1.IpiNivo_CompleteResponse_Center Kidney Krishna
#                                                    Stage_Corrected
# GCACTCTTCTCTGTCG-1.IpiNivo_CompleteResponse_Center IV
#                                                    Stage_Corrected_EarlyLate
# GCACTCTTCTCTGTCG-1.IpiNivo_CompleteResponse_Center Late
#                                                    Treated IO_Treated IO  TKI
# GCACTCTTCTCTGTCG-1.IpiNivo_CompleteResponse_Center Yes     IO Exposed Yes Yes

# %%
Krishna_SampleName = unique(Krishna$SampleName)
subset(Krishna, SampleName == Krishna_SampleName[[17]])[1,]

#Passed
# Out:
#                                                     Patient
# GTATCTTAGCCCGAAA-1.IpiNivo_CompleteResponse_Lateral IpiNivo_CompleteResponse
#                                                     SampleName
# GTATCTTAGCCCGAAA-1.IpiNivo_CompleteResponse_Lateral IpiNivo_CompleteResponse_Lateral
#                                                     Sample
# GTATCTTAGCCCGAAA-1.IpiNivo_CompleteResponse_Lateral IpiNivo_CompleteResponse_Lateral
#                                                     Biopsy Cohort
# GTATCTTAGCCCGAAA-1.IpiNivo_CompleteResponse_Lateral Kidney Krishna
#                                                     Stage_Corrected
# GTATCTTAGCCCGAAA-1.IpiNivo_CompleteResponse_Lateral IV
#                                                     Stage_Corrected_EarlyLate
# GTATCTTAGCCCGAAA-1.IpiNivo_CompleteResponse_Lateral Late
#                                                     Treated IO_Treated IO  TKI
# GTATCTTAGCCCGAAA-1.IpiNivo_CompleteResponse_Lateral Yes     IO Exposed Yes Yes

# %%
Krishna_SampleName = unique(Krishna$SampleName)
subset(Krishna, SampleName == Krishna_SampleName[[18]])[1,]

#Passed
# Out:
#                                                    Patient
# ACGGGCTGTTCTCATT-1.IpiNivo_CompleteResponse_Medial IpiNivo_CompleteResponse
#                                                    SampleName
# ACGGGCTGTTCTCATT-1.IpiNivo_CompleteResponse_Medial IpiNivo_CompleteResponse_Medial
#                                                    Sample
# ACGGGCTGTTCTCATT-1.IpiNivo_CompleteResponse_Medial IpiNivo_CompleteResponse_Medial
#                                                    Biopsy Cohort
# ACGGGCTGTTCTCATT-1.IpiNivo_CompleteResponse_Medial Kidney Krishna
#                                                    Stage_Corrected
# ACGGGCTGTTCTCATT-1.IpiNivo_CompleteResponse_Medial IV
#                                                    Stage_Corrected_EarlyLate
# ACGGGCTGTTCTCATT-1.IpiNivo_CompleteResponse_Medial Late
#                                                    Treated IO_Treated IO  TKI
# ACGGGCTGTTCTCATT-1.IpiNivo_CompleteResponse_Medial Yes     IO Exposed Yes Yes

# %%
Krishna_SampleName = unique(Krishna$SampleName)
subset(Krishna, SampleName == Krishna_SampleName[[19]])[1,]

#Passed
# Out:
#                              Patient SampleName Sample    Biopsy Cohort
# TGCGCAGTCTTCATGT-1.UT1_Lower UT1     UT1_Lower  UT1_Lower Kidney Krishna
#                              Stage_Corrected Stage_Corrected_EarlyLate Treated
# TGCGCAGTCTTCATGT-1.UT1_Lower III             Late                      No
#                              IO_Treated IO TKI
# TGCGCAGTCTTCATGT-1.UT1_Lower IO Naive   No No

# %% [markdown]
# ### Krishna cohort - all samples passed manual metadata check

# %% [markdown]
# ### Figure 1B. Prepare metadata for CoMut  <a name="6"></a>

# %% [markdown]
# ### Add grade, sex, and age for all cohorts before CoMut

# %%
comut = seur_full@meta.data
comut = comut[,c("Sample","SampleName","Patient","Cohort","Chemistry","Treated","IO","TKI","IO_Treated","Biopsy","Stage_Corrected","Location","Histology")]
colnames(comut)
# Out:
#  [1] "Sample"          "SampleName"      "Patient"         "Cohort"
#  [5] "Chemistry"       "Treated"         "IO"              "TKI"
#  [9] "IO_Treated"      "Biopsy"          "Stage_Corrected" "Location"
# [13] "Histology"

# %%
row.names(comut) = NULL
comut_collapsed = unique(comut)
head(comut_collapsed)
# Out:
#      Sample                  SampleName Patient Cohort Chemistry Treated IO TKI
# 1    5pool1_2                S1_T       S1      Braun  5prime    No      No No
# 404  Bi_0600855_T3           P55        P55     Bi     3prime    Yes     PR Yes
# 493  Bi_0600906_T1           P906       P906    Bi     3prime    Yes     PD Yes
# 1121 Bi_0600913_T1           P913       P913    Bi     3prime    Yes     SD Yes
# 1310 Bi_0600915_T1_TrueTumor P915       P915    Bi     3prime    Yes     PR No
# 1866 Bi_0600916_T1           P916       P916    Bi     3prime    No      No No
#      IO_Treated Biopsy     Stage_Corrected Location Histology
# 1    IO Naive   Kidney     I               None     ccRCC
# 404  IO Exposed Abdomen    IV              None     ccRCC
# 493  IO Exposed Lymph_node IV              None     pRCC
# 1121 IO Exposed Lung       IV              None     ccRCC
# 1310 IO Exposed Kidney     III             None     ccRCC
# 1866 IO Naive   Lymph_node IV              None     ccRCC

# %%
add = read.table("../Data_Objects/metadata_add_forCoMut.txt",header = T, sep = '\t')
add = subset(add, select = -c(Cohort))
head(add)
# Out:
#   Patient Sex    Age      Grade
# 1 S1      Female 62.50959 2
# 2 S2      Male   54.74795 3
# 3 S3      Male   54.68493 3
# 4 S5      Male   50.17260 4
# 5 S6      Male   67.22192 2
# 6 S7      Female 78.75068 3

# %%
comut_collapsed_added = left_join(comut_collapsed, add, by = "Patient")
head(comut_collapsed_added)
# Out:
#   Sample                  SampleName Patient Cohort Chemistry Treated IO TKI
# 1 5pool1_2                S1_T       S1      Braun  5prime    No      No No
# 2 Bi_0600855_T3           P55        P55     Bi     3prime    Yes     PR Yes
# 3 Bi_0600906_T1           P906       P906    Bi     3prime    Yes     PD Yes
# 4 Bi_0600913_T1           P913       P913    Bi     3prime    Yes     SD Yes
# 5 Bi_0600915_T1_TrueTumor P915       P915    Bi     3prime    Yes     PR No
# 6 Bi_0600916_T1           P916       P916    Bi     3prime    No      No No
#   IO_Treated Biopsy     Stage_Corrected Location Histology Sex    Age
# 1 IO Naive   Kidney     I               None     ccRCC     Female 62.50959
# 2 IO Exposed Abdomen    IV              None     ccRCC     Male   57.00000
# 3 IO Exposed Lymph_node IV              None     pRCC      Male   62.00000
# 4 IO Exposed Lung       IV              None     ccRCC     Male   47.00000
# 5 IO Exposed Kidney     III             None     ccRCC     Male   58.00000
# 6 IO Naive   Lymph_node IV              None     ccRCC     Male   61.00000
#   Grade
# 1 2
# 2 3
# 3 3
# 4 4
# 5 3
# 6 4

# %%
comut_collapsed_added = comut_collapsed_added %>% arrange(Cohort,Treated,Patient)
head(comut_collapsed_added)
# Out:
#   Sample             SampleName Patient Cohort Chemistry Treated IO TKI
# 1 Bi_DFCI_0600876_T1 P76        P76     Bi     3prime    No      No No
# 2 Bi_DFCI_0600890_T1 P90        P90     Bi     3prime    No      No No
# 3 Bi_0600916_T1      P916       P916    Bi     3prime    No      No No
# 4 Bi_0600855_T3      P55        P55     Bi     3prime    Yes     PR Yes
# 5 Bi_0600906_T1      P906       P906    Bi     3prime    Yes     PD Yes
# 6 Bi_0600912_T1      P912       P912    Bi     3prime    Yes     NE Yes
#   IO_Treated Biopsy     Stage_Corrected Location Histology Sex    Age Grade
# 1 IO Naive   Kidney     IV              None     ccRCC     Female 68  4
# 2 IO Naive   Kidney     I               None     ccRCC     Female 71  4
# 3 IO Naive   Lymph_node IV              None     ccRCC     Male   61  4
# 4 IO Exposed Abdomen    IV              None     ccRCC     Male   57  3
# 5 IO Exposed Lymph_node IV              None     pRCC      Male   62  3
# 6 IO Exposed Lymph_node IV              None     ccRCC     Male   60  4

# %% [markdown]
# ### Make a categorical age column

# %%
comut_collapsed_added = mutate(comut_collapsed_added, Age_Categorical = ifelse(Age >= 40 & Age < 50, "40-50",ifelse(Age >= 50 & Age < 60, "50-60",ifelse(Age >= 60 & Age < 70, "60-70",ifelse(Age >= 70, "70+","None")))))
table(comut_collapsed_added$Age_Categorical)
# Out:
# 40-50 50-60 60-70   70+
#     1    16    19     6

# %% [markdown]
# ### Make a column for patient with numerical groups

# %%
df = data.frame(unique(comut_collapsed_added$Patient), 1:length(unique(comut_collapsed_added$Patient)))
colnames(df) = c("Patient","Patient_Numeric")
head(df)
# Out:
#   Patient Patient_Numeric
# 1 P76     1
# 2 P90     2
# 3 P916    3
# 4 P55     4
# 5 P906    5
# 6 P912    6

# %%
comut_collapsed_added = left_join(comut_collapsed_added,df, by = "Patient")
head(comut_collapsed_added)
# Out:
#   Sample             SampleName Patient Cohort Chemistry Treated IO TKI
# 1 Bi_DFCI_0600876_T1 P76        P76     Bi     3prime    No      No No
# 2 Bi_DFCI_0600890_T1 P90        P90     Bi     3prime    No      No No
# 3 Bi_0600916_T1      P916       P916    Bi     3prime    No      No No
# 4 Bi_0600855_T3      P55        P55     Bi     3prime    Yes     PR Yes
# 5 Bi_0600906_T1      P906       P906    Bi     3prime    Yes     PD Yes
# 6 Bi_0600912_T1      P912       P912    Bi     3prime    Yes     NE Yes
#   IO_Treated Biopsy     Stage_Corrected Location Histology Sex    Age Grade
# 1 IO Naive   Kidney     IV              None     ccRCC     Female 68  4
# 2 IO Naive   Kidney     I               None     ccRCC     Female 71  4
# 3 IO Naive   Lymph_node IV              None     ccRCC     Male   61  4
# 4 IO Exposed Abdomen    IV              None     ccRCC     Male   57  3
# 5 IO Exposed Lymph_node IV              None     pRCC      Male   62  3
# 6 IO Exposed Lymph_node IV              None     ccRCC     Male   60  4
#   Age_Categorical Patient_Numeric
# 1 60-70           1
# 2 70+             2
# 3 60-70           3
# 4 50-60           4
# 5 60-70           5
# 6 60-70           6

# %%
comut_collapsed_added = comut_collapsed_added %>% arrange(Cohort,Stage_Corrected,Treated,Patient)
comut_collapsed_added
# Out:
#    Sample                           SampleName
# 1  Bi_DFCI_0600890_T1               P90
# 2  Bi_0600915_T1_TrueTumor          P915
# 3  Bi_DFCI_0600876_T1               P76
# 4  Bi_0600916_T1                    P916
# 5  Bi_0600855_T3                    P55
# 6  Bi_0600906_T1                    P906
# 7  Bi_0600912_T1                    P912
# 8  Bi_0600913_T1                    P913
# 9  5pool1_2                         S1_T
# 10 Pool70-6                         S2_T
# 11 Pool71-3                         S6_T
# 12 Pool72-2                         S8_T
# 13 Pool73-6                         S12_V
# 14 Pool71-8                         S12_T
# 15 Pool72-4                         S14_T
# 16 Pool70-8                         S3_T
# 17 Pool73-3                         S7_T
# 18 Pool72-10                        S10_T
# 19 Pool71-5                         S11_T
# 20 Pool71-6                         S11_M
# 21 Pool73-4                         S15_T
# 22 Pool73-5                         S16_T
# 23 Pool70-10                        S5_T
# 24 UT1_Center                       UT1_Center
# 25 UT1_Upper                        UT1_Upper
# 26 UT1_Lower                        UT1_Lower
# 27 NivoExposed_LowerLateral         NivoExposed_LowerLateral
# 28 NivoExposed_LowerMedial          NivoExposed_LowerMedial
# 29 NivoExposed_SupraLateral         NivoExposed_SupraLateral
# 30 UT2_Center                       UT2_Center
# 31 UT2_Far                          UT2_Far
# 32 UT2_Near                         UT2_Near
# 33 IpiNivo_CompleteResponse_Center  IpiNivo_CompleteResponse_Center
# 34 IpiNivo_CompleteResponse_Lateral IpiNivo_CompleteResponse_Lateral
# 35 IpiNivo_CompleteResponse_Medial  IpiNivo_CompleteResponse_Medial
# 36 IpiNivo_Mixed_Center             IpiNivo_Mixed_Center
# 37 IpiNivo_Mixed_Far                IpiNivo_Mixed_Far
# 38 IpiNivo_Mixed_Near               IpiNivo_Mixed_Near
# 39 IpiNivo_Resistant_Center         IpiNivo_Resistant_Center
# 40 IpiNivo_Resistant_Far            IpiNivo_Resistant_Far
# 41 IpiNivo_Resistant_LymphNode      IpiNivo_Resistant_LymphNode
# 42 IpiNivo_Resistant_Near           IpiNivo_Resistant_Near
#    Patient                  Cohort  Chemistry Treated IO  TKI IO_Treated
# 1  P90                      Bi      3prime    No      No  No  IO Naive
# 2  P915                     Bi      3prime    Yes     PR  No  IO Exposed
# 3  P76                      Bi      3prime    No      No  No  IO Naive
# 4  P916                     Bi      3prime    No      No  No  IO Naive
# 5  P55                      Bi      3prime    Yes     PR  Yes IO Exposed
# 6  P906                     Bi      3prime    Yes     PD  Yes IO Exposed
# 7  P912                     Bi      3prime    Yes     NE  Yes IO Exposed
# 8  P913                     Bi      3prime    Yes     SD  Yes IO Exposed
# 9  S1                       Braun   5prime    No      No  No  IO Naive
# 10 S2                       Braun   5prime    No      No  No  IO Naive
# 11 S6                       Braun   5prime    No      No  No  IO Naive
# 12 S8                       Braun   5prime    No      No  No  IO Naive
# 13 S12                      Braun   5prime    No      No  No  IO Naive
# 14 S12                      Braun   5prime    No      No  No  IO Naive
# 15 S14                      Braun   5prime    No      No  No  IO Naive
# 16 S3                       Braun   5prime    No      No  No  IO Naive
# 17 S7                       Braun   5prime    No      No  No  IO Naive
# 18 S10                      Braun   5prime    No      No  No  IO Naive
# 19 S11                      Braun   5prime    No      No  No  IO Naive
# 20 S11                      Braun   5prime    No      No  No  IO Naive
# 21 S15                      Braun   5prime    No      No  No  IO Naive
# 22 S16                      Braun   5prime    No      No  No  IO Naive
# 23 S5                       Braun   5prime    No      No  No  IO Naive
# 24 UT1                      Krishna 5prime    No      No  No  IO Naive
# 25 UT1                      Krishna 5prime    No      No  No  IO Naive
# 26 UT1                      Krishna 5prime    No      No  No  IO Naive
# 27 NivoExposed              Krishna 5prime    Yes     Yes No  IO Exposed
# 28 NivoExposed              Krishna 5prime    Yes     Yes No  IO Exposed
# 29 NivoExposed              Krishna 5prime    Yes     Yes No  IO Exposed
# 30 UT2                      Krishna 5prime    No      No  No  IO Naive
# 31 UT2                      Krishna 5prime    No      No  No  IO Naive
# 32 UT2                      Krishna 5prime    No      No  No  IO Naive
# 33 IpiNivo_CompleteResponse Krishna 5prime    Yes     Yes Yes IO Exposed
# 34 IpiNivo_CompleteResponse Krishna 5prime    Yes     Yes Yes IO Exposed
# 35 IpiNivo_CompleteResponse Krishna 5prime    Yes     Yes Yes IO Exposed
# 36 IpiNivo_Mixed            Krishna 5prime    Yes     Yes No  IO Exposed
# 37 IpiNivo_Mixed            Krishna 5prime    Yes     Yes No  IO Exposed
# 38 IpiNivo_Mixed            Krishna 5prime    Yes     Yes No  IO Exposed
# 39 IpiNivo_Resistant        Krishna 5prime    Yes     Yes No  IO Exposed
# 40 IpiNivo_Resistant        Krishna 5prime    Yes     Yes No  IO Exposed
# 41 IpiNivo_Resistant        Krishna 5prime    Yes     Yes No  IO Exposed
# 42 IpiNivo_Resistant        Krishna 5prime    Yes     Yes No  IO Exposed
#    Biopsy                    Stage_Corrected Location Histology Sex    Age
# 1  Kidney                    I               None     ccRCC     Female 71.00000
# 2  Kidney                    III             None     ccRCC     Male   58.00000
# 3  Kidney                    IV              None     ccRCC     Female 68.00000
# 4  Lymph_node                IV              None     ccRCC     Male   61.00000
# 5  Abdomen                   IV              None     ccRCC     Male   57.00000
# 6  Lymph_node                IV              None     pRCC      Male   62.00000
# 7  Lymph_node                IV              None     ccRCC     Male   60.00000
# 8  Lung                      IV              None     ccRCC     Male   47.00000
# 9  Kidney                    I               None     ccRCC     Female 62.50959
# 10 Kidney                    I               None     ccRCC     Male   54.74795
# 11 Kidney                    I               None     ccRCC     Male   67.22192
# 12 Kidney                    II              None     ccRCC     Female 61.14521
# 13 Renal_vein_tumor_thrombus III             None     ccRCC     Male   61.15068
# 14 Kidney                    III             None     ccRCC     Male   61.15068
# 15 Kidney                    III             None     ccRCC     Male   71.86849
# 16 Kidney                    III             None     ccRCC     Male   54.68493
# 17 Kidney                    III             None     ccRCC     Female 78.75068
# 18 Kidney                    IV              None     ccRCC     Female 83.29041
# 19 Kidney                    IV              None     ccRCC     Male   79.97260
# 20 Abdomen                   IV              None     ccRCC     Male   79.97260
# 21 Kidney                    IV              None     ccRCC     Male   52.49041
# 22 Kidney                    IV              None     ccRCC     Male   61.20274
# 23 Adrenal                   IV              None     ccRCC     Male   50.17260
# 24 Kidney                    III             Center   ccRCC     Female 69.00000
# 25 Kidney                    III             Upper    ccRCC     Female 69.00000
# 26 Kidney                    III             Lower    ccRCC     Female 69.00000
# 27 Kidney                    III             Far      ccRCC     Male   54.00000
# 28 Kidney                    III             Center   ccRCC     Male   54.00000
# 29 Kidney                    III             Near     ccRCC     Male   54.00000
# 30 Kidney                    IV              Center   ccRCC     Female 57.00000
# 31 Kidney                    IV              Far      ccRCC     Female 57.00000
# 32 Kidney                    IV              Near     ccRCC     Female 57.00000
# 33 Kidney                    IV              Center   ccRCC     Male   63.00000
# 34 Kidney                    IV              Far      ccRCC     Male   63.00000
# 35 Kidney                    IV              Near     ccRCC     Male   63.00000
# 36 Kidney                    IV              Center   ccRCC     Male   64.00000
# 37 Kidney                    IV              Far      ccRCC     Male   64.00000
# 38 Kidney                    IV              Near     ccRCC     Male   64.00000
# 39 Kidney                    IV              Center   ccRCC     Male   50.00000
# 40 Kidney                    IV              Far      ccRCC     Male   50.00000
# 41 Lymph_node                IV              Met      ccRCC     Male   50.00000
# 42 Kidney                    IV              Near     ccRCC     Male   50.00000
#    Grade Age_Categorical Patient_Numeric
# 1   4    70+              2
# 2   3    50-60            8
# 3   4    60-70            1
# 4   4    60-70            3
# 5   3    50-60            4
# 6   3    60-70            5
# 7   4    60-70            6
# 8   4    40-50            7
# 9   2    60-70            9
# 10  3    50-60           16
# 11  2    60-70           19
# 12  2    60-70           21
# 13  2    60-70           12
# 14  2    60-70           12
# 15  3    70+             13
# 16  3    50-60           17
# 17  3    70+             20
# 18  3    70+             10
# 19  4    70+             11
# 20  4    70+             11
# 21  2    50-60           14
# 22  4    60-70           15
# 23  4    50-60           18
# 24 NA    60-70           22
# 25 NA    60-70           22
# 26 NA    60-70           22
# 27 NA    50-60           27
# 28 NA    50-60           27
# 29 NA    50-60           27
# 30 NA    50-60           23
# 31 NA    50-60           23
# 32 NA    50-60           23
# 33 NA    60-70           24
# 34 NA    60-70           24
# 35 NA    60-70           24
# 36 NA    60-70           25
# 37 NA    60-70           25
# 38 NA    60-70           25
# 39 NA    50-60           26
# 40 NA    50-60           26
# 41 NA    50-60           26
# 42 NA    50-60           26

# %%
saveRDS(comut_collapsed_added, file = "../Figures/Figure1/final_comut_collapsed_data.RDS")
write.table(comut_collapsed_added, file = "../Figures/Figure1/comut_collapsed_added.txt", sep = '\t',quote = F,col.names = NA)

# %% [markdown]
# ### Establish some color palettes for CoMut and later plotting

# %%
Biopsy_mapping : {'Abdomen':'#66C2A5','Adrenal':'#FC8D62','Kidney':'#8DA0CB','Lung':'#E78AC3','Lymph_node':'#A6D854','Renal_vein_tumor_thrombus':'#FFD92F'}

# %%
levels(factor(seur_goodcells$Biopsy))
# Out:
# [1] "Abdomen"                   "Adrenal"
# [3] "Kidney"                    "Lung"
# [5] "Lymph_node"                "Renal_vein_tumor_thrombus"

# %%
brewer.pal(6,"Set2")
# Out:
# [1] "#66C2A5" "#FC8D62" "#8DA0CB" "#E78AC3" "#A6D854" "#FFD92F"

# %%
display.brewer.pal(6, "Set2")
# Out:
# plot without title

# %%
Stage_mapping = {'I':'#fcf9ce','II':'#a3d6b3','III':'#40b6c4','IV':'#225fa9'}

# %%
Grade_mapping = {'2.0':"#fde0dd","3.0":"#fa9fb5","4.0":"#c51b8a","nan":"#d9d9d9"}

# %%
Age_Categorical_mapping = {'40-50':"#edf8fb","50-60":"#b3cde3","60-70":"#8c96c6","70+":"#88419d"}

# %%
Sex_mapping = {'Male':"#fee5d9","Female":"#cb181d"}

# %%
TKI_mapping = {'No':'#ffffd4','Yes':"#993404"}

# %%
Cohort_mapping = {'Bi':"#e21e26","Braun":"#262262","Krishna":"#4eaf49"}
